# %% [markdown]
# <img style="float: center;" src='https://github.com/STScI-MIRI/MRS-ExampleNB/raw/main/assets/banner1.png' alt="stsci_logo" width="1000px"/><br>
#
# ----
# # NIRSpec BOTS pipeline rerun
# ----
#
# **Author**: Nikolay Nikolov, AURA Associate Scientist, NIRSpec branch
# <br>
# **Pipeline Version**: 1.12.5
# <br>
# **Last Update**: January 04, 2024

# %% [markdown]
# ## <font color='white'>-</font>Table of contents<a class="anchor" id="table"></a>
# 1. [Introduction and setup](#intro)<br>
# 2. [Data download](#download)<br>
# 3. [Stage 1: Detector1Pipeline](#stage1)<br>
# 4. [Stage 2: Spec2Pipeline](#stage2)<br>
# 5. [Stage 3: Tso3Pipeline](#stage3)<br>
# 6. [Concluding remarks](#remarks)<br>

# %% [markdown]
# ---
#
# ### 1.<font color='white'>-</font>Introduction and setup<a class="anchor" id="intro"></a>
#
# ---
#
# The purpose of this notebook is to demonstrate how to re-run the three stages of the STScI pipeline for NIRSpec BOTS. At the time of creating this notebook, the pipeline continues to be imporved. In order to deliver useful products for light curve alnalysis, this notebook provides a guidance to how to rerun the pipeline and also offests a work around solution for the 1/f-noise clean step. Prior to performing data analysis, we import all the needed libraries and set up paths.

# %%
# General functions
import os
import time as tt
import pickle
import cv2
import tqdm
import shutil

import numpy as np

# Multiprocessing functions
import multiprocessing as mp


# Astroquerry
import astroquery
from astroquery.mast import Observations

# JWST Pipeline
import jwst
import crds
from jwst import datamodels
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Spec2Pipeline
from jwst.pipeline import Tso3Pipeline
from jwst.assign_wcs import nirspec

# Plot functions
import matplotlib.pyplot as plt

import pandas as pd
from astropy.table import Table

#%set_env CRDS_PATH /path/to/my/folder/
#%set_env CRDS_SERVER_URL https://jwst-crds.stsci.edu

print("JWST Calibration Pipeline Version={}".format(jwst.__version__))
print("Current Operational CRDS Context = {}".format(crds.get_default_context()))
print("Number of processors: ", mp.cpu_count())
# Out:
# JWST Calibration Pipeline Version=1.12.5
# Current Operational CRDS Context = jwst_1177.pmap
# Number of processors:  12

# %% [markdown]
# #### [Link to the Table of contents](#table)

# %% [markdown]
# ---
#
# ### 2.<font color='white'>-</font>Data download <a class="anchor" id="download"></a>
#
# ---
#
# The input data for this notebook is a transit of WASP-39b, observed in the BOTS G395H grism. The data set belongs to the <a href="https://www.stsci.edu/jwst/science-execution/approved-programs/dd-ers/program-1366">JWST Early Release Science program ERS-1366,</a> observation 3, and includes 456 integrations of 70 groups each with the SUB2048 subarray (array size of 2048 by 32 pixels per integration, per group), covering a total of 10.56 hours. The data set consists of three segments of `uncal` files, each with a size of 1.42 GB.
#
# Information of existing and planned JWST TSO programs of transiting exoplanets, including with the NIRSpec BOTS mode, can be obtained from <a href="https://www.stsci.edu/~nnikolov/TrExoLiSTS/JWST/trexolists.html">TrExoLiSTS</a>

# %%
process_detector = 'nrs1' # choose 'nrs1', 'nrs2'

# Define the rateints files (aka slope or rate images)
if process_detector == 'nrs1':
    files = ['jw01366003001_04101_00001-seg001_nrs1_uncal.fits',
             'jw01366003001_04101_00001-seg002_nrs1_uncal.fits',
             'jw01366003001_04101_00001-seg003_nrs1_uncal.fits']

if process_detector == 'nrs2':
    files = ['jw01366003001_04101_00001-seg001_nrs2_uncal.fits', 
             'jw01366003001_04101_00001-seg002_nrs2_uncal.fits',
             'jw01366003001_04101_00001-seg003_nrs2_uncal.fits']

asn_spec3_file = 'jw01366-o003_20230901t213306_tso3_00001_asn.json'

# %%
# Extract rootnames. We will use these to determine which file names to be analyzed
froot = [files[i].replace('uncal.fits', '') for i in range(len(files))]
print(froot)
# Out:
# ['jw01366003001_04101_00001-seg001_nrs1_', 'jw01366003001_04101_00001-seg002_nrs1_', 'jw01366003001_04101_00001-seg003_nrs1_']

# %% [markdown]
# Next, the notebook will create folder structure for the data and pipeline products from the three stages. When the notebook is run for the first time, it will also download the data and put it in the  data directory. Data download will be skipped, if the data directory with files already exists.

# %%
working_dir = os.getcwd()+'/'

data_dir   = working_dir + 'data/'
stage1_dir = working_dir + 'stage1/'
stage2_dir = working_dir + 'stage2/'
stage3_dir = working_dir + 'stage3/'

    
if not os.path.exists(data_dir):
    print('Creating ' + data_dir + ' ...')
    os.makedirs(data_dir)

if not os.path.exists(stage1_dir):
    print('Creating ' + stage1_dir + ' ...')
    os.makedirs(stage1_dir)

if not os.path.exists(stage2_dir):
    print('Creating ' + stage2_dir + ' ...')
    os.makedirs(stage2_dir)

if not os.path.exists(stage3_dir):
    print('Creating ' + stage3_dir + ' ...')
    os.makedirs(stage3_dir)


# Download the uncal files, if not currently present
mast_dir = 'mast:jwst/product'
for i in range(len(files)):
    if os.path.isfile(data_dir+files[i]):
        print('Uncal files found in the data directory. Not downloading ...')
    if not os.path.isfile(data_dir+files[i]):
        print('Uncal files missing in the data directory. Now downloading ...')
        mast_path  = os.path.join(mast_dir, files[i])
        local_path = os.path.join(data_dir, files[i])
        Observations.download_file(mast_path, cache=False)
        shutil.move(working_dir+files[i], data_dir)

if not os.path.isfile(stage2_dir+asn_spec3_file):
    print('TSO3 association file is missing in the stage2 directory. Now downloading ...')
    mast_path  = os.path.join(mast_dir, asn_spec3_file)
    local_path = os.path.join(stage2_dir, asn_spec3_file)
    Observations.download_file(mast_path, cache=False)
    shutil.move(working_dir+asn_spec3_file, stage2_dir)
# Out:
# Uncal files found in the data directory. Not downloading ...
# Uncal files found in the data directory. Not downloading ...
# Uncal files found in the data directory. Not downloading ...

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Data download](#download), [Link to Stage2](#stage2), [Link to Stage3](#stage3)

# %% [markdown]
# ---
# ### <font color='white'>-</font>Stage 1: Detector1Pipeline<a class="anchor" id="stage1"></a>
#
# ---

# %% [markdown]
# This step applies basic detector-level corrections to all exposure types, and it is seldom refered as 'ramps-to-slopes' processing. For more information regarding the individual steps applied on NIRSpec BOTS data, please consult: <a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_detector1.html">calwebb_detector1: Stage 1 Detector Processing.</a>
#
#
# First, define a dictionary with all steps needed for BOTS, and include parameters accordingly. To perform or skip a step in the pipeline, one specifies the attribute `skip` in the parameter dictionary and assigns a value `False` for executing, or `True` for skipping the step.
#
# This step takes approximately 25 minutes for the three segments of the NRS1 detector.

# %%
from jwst.pipeline import Detector1Pipeline

# %%
param_stage1 = {
    'group_scale'     :{'skip': False}, # not relevant for BOTS
    'dq_init'         :{'skip': False},
    'saturation'      :{'skip': False},
    'superbias'       :{'skip': False},
    'refpix'          :{'skip': False, 'odd_even_rows': True},
    'linearity'       :{'skip': False},
    'dark_current'    :{'skip': False},
    'jump'            :{'skip': False, 'maximum_cores': 'half', 'rejection_threshold': 4.0},    # options for maximum cores: an integer, ‘all’, ‘half’ or ‘quarter’
    'ramp_fit'        :{'skip': False, 'maximum_cores': 'half'},
    'gain_scale'      :{'skip': False} # not relevant for BOTS
}

start = tt.time()

for i in range(len(files)):
    Detector1Pipeline.call(data_dir + files[i], 
                           save_results = True, 
                           steps        = param_stage1, 
                           output_dir   = stage1_dir)

end = tt.time()
print("Run time: ", round(end-start,1)/60.0, " min")
# Out:
# 2023-12-20 17:24:00,046 - CRDS - ERROR -  Error determining best reference for 'pars-chargemigrationstep'  =   Unknown reference type 'pars-chargemigrationstep'
# 2023-12-20 17:24:00,048 - stpipe - INFO - PARS-JUMPSTEP parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-jumpstep_0002.asdf
# 2023-12-20 17:24:00,057 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-detector1pipeline_0003.asdf
# 2023-12-20 17:24:00,118 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2023-12-20 17:24:00,119 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2023-12-20 17:24:00,120 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2023-12-20 17:24:00,121 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2023-12-20 17:24:00,121 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2023-12-20 17:24:00,122 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2023-12-20 17:24:00,123 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2023-12-20 17:24:00,123 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2023-12-20 17:24:00,124 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2023-12-20 17:24:00,125 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2023-12-20 17:24:00,126 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2023-12-20 17:24:00,127 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2023-12-20 17:24:00,127 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2023-12-20 17:24:00,128 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2023-12-20 17:24:00,129 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2023-12-20 17:24:00,130 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2023-12-20 17:24:00,131 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2023-12-20 17:24:00,132 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2023-12-20 17:24:00,186 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data/jw01366003001_04101_00001-seg001_nrs1_uncal.fits',).
# 2023-12-20 17:24:00,193 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': True, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_us ...
# 2023-12-20 17:24:01,154 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01366003001_04101_00001-seg001_nrs1_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'saturation', 'superbias']
# 2023-12-20 17:24:01,157 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0298.fits'.
# 2023-12-20 17:24:01,158 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0025.fits'.
# 2023-12-20 17:24:01,159 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits'.
# 2023-12-20 17:24:01,160 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0051.fits'.
# 2023-12-20 17:24:01,160 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits'.
# 2023-12-20 17:24:01,161 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2023-12-20 17:24:01,161 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# 2023-12-20 17:24:01,161 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits'.
# 2023-12-20 17:24:01,162 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits'.
# 2023-12-20 17:24:01,163 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2023-12-20 17:24:03,690 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_uncal.fits>,).
# 2023-12-20 17:24:03,691 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:24:05,222 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2023-12-20 17:24:05,223 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2023-12-20 17:24:05,225 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 
- stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}
# 2023-12-20 17:33:09,473 - stpipe.Detector1Pipeline.refpix - INFO - NIR subarray data
# 2023-12-20 17:33:09,475 - stpipe.Detector1Pipeline.refpix - INFO - Single readout amplifier used
# 2023-12-20 17:33:09,475 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2023-12-20 17:33:09,476 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2023-12-20 17:33:09,476 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2023-12-20 17:33:09,476 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2023-12-20 17:33:09,477 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2023-12-20 17:33:09,477 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.0
# 2023-12-20 17:33:09,477 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = False
# 2023-12-20 17:33:45,548 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2023-12-20 17:33:45,822 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs1_uncal.fits>,).
# 2023-12-20 17:33:45,823 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:33:45,842 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2023-12-20 17:33:45,875 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-12-20 17:33:49,077 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2023-12-20 17:33:49,356 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs1_uncal.fits>,).
# 2023-12-20 17:33:49,357 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'dark_output': None}
# 2023-12-20 17:33:49,375 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0298.fits
# 2023-12-20 17:33:49,426 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=155, ngroups=70, nframes=1, groupgap=0
# 2023-12-20 17:33:49,427 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=120, nframes=1, groupgap=0
# 2023-12-20 17:33:53,066 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2023-12-20 17:33:53,349 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs1_uncal.fits>,).
# 2023-12-20 17:33:53,350 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'signal_threshold': 25000.0}
# 2023-12-20 17:33:53,350 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2023-12-20 17:33:53,353 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration done
# 2023-12-20 17:33:53,406 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs1_uncal.fits>,).
# 2023-12-20 17:33:53,408 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 1000, 'after_jump_flag_time1': 90, 'after_jump_flag_dn2': 0, 'after_jump_flag_time2': 0, 'expand_large_events': False, 'min_sat_area': 1, 'min_jump_area': 5, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'edge_size': 25, 'find_showers': False, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200, 'minimum_groups': 3, 'minimum_sigclip_groups': 100, 'only_use_ints': True}
# 2023-12-20 17:33:53,416 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2023-12-20 17:33:53,417 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2023-12-20 17:33:53,428 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2023-12-20 17:33:53,461 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2023-12-20 17:33:55,149 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# ...
# 2023-12-20 17:41:06,342 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0028.fits
# 2023-12-20 17:41:07,937 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2023-12-20 17:41:28,013 - stpipe.Detector1Pipeline.saturation - INFO - Detected 678 saturated pixels
# 2023-12-20 17:41:28,256 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2023-12-20 17:41:28,263 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2023-12-20 17:41:28,542 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:41:28,543 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:41:28,544 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2023-12-20 17:41:28,546 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2023-12-20 17:41:28,597 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:41:28,597 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:41:28,615 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0427.fits
# 2023-12-20 17:41:30,386 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2023-12-20 17:41:30,662 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:41:30,663 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}
# 2023-12-20 17:41:32,383 - stpipe.Detector1Pipeline.refpix - INFO - NIR subarray data
# 2023-12-20 17:41:32,385 - stpipe.Detector1Pipeline.refpix - INFO - Single readout amplifier used
# 2023-12-20 17:41:32,385 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2023-12-20 17:41:32,385 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2023-12-20 17:41:32,385 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2023-12-20 17:41:32,386 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2023-12-20 17:41:32,386 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2023-12-20 17:41:32,386 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.0
# 2023-12-20 17:41:32,386 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = False
# 2023-12-20 17:42:07,596 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2023-12-20 17:42:07,851 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:42:07,852 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:42:07,868 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0024.fits
# 2023-12-20 17:42:07,898 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-12-20 17:42:10,873 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2023-12-20 17:42:11,118 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:42:11,119 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'dark_output': None}
# 2023-12-20 17:42:11,136 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0298.fits
# 2023-12-20 17:42:11,183 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=155, ngroups=70, nframes=1, groupgap=0
# 2023-12-20 17:42:11,184 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=120, nframes=1, groupgap=0
# 2023-12-20 17:42:14,594 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2023-12-20 17:42:14,848 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:42:14,849 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'signal_threshold': 25000.0}
# 2023-12-20 17:42:14,849 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2023-12-20 17:42:14,851 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration done
# 2023-12-20 17:42:14,899 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_uncal.fits>,).
# 2023-12-20 17:42:14,901 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 1000, 'after_jump_flag_time1': 90, 'after_jump_flag_dn2': 0, 'after_jump_flag_time2': 0, 'expand_large_events': False, 'min_sat_area': 1, 'min_jump_area': 5, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'edge_size': 25, 'find_showers': False, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200, 'minimum_groups': 3, 'minimum_sigclip_groups': 100, 'only_use_ints': True}
# 2023-12-20 17:42:14,908 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2023-12-20 17:42:14,908 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2023-12-20 17:42:14,918 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2023-12-20 17:42:14,948 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2023-12-20 17:42:16,516 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# 2023-12-20 17:42:16,517 - stpipe.Detector1Pipeline.jump - INFO - Extracting readnoise subarray to match science data
# 2023-12-20 17:42:16,758 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2023-12-20 17:42:17,517 - stpipe.Detector1Pipeline.jump - INFO - Creating 6 processes for jump detection
# 2023-12-20 17:43:27,141 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 70.3817 sec
# 2023-12-20 17:43:28,308 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:405: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 17:43:28,308 - stpipe.Detector1Pipeline.jump - WARNING -   data /= gain_2d
# 2023-12-20 17:43:28,309 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 17:43:29,247 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:406: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 17:43:29,248 - stpipe.Detector1Pipeline.jump - WARNING -   err /= gain_2d
# 2023-12-20 17:43:29,248 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 17:43:29,249 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:407: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 17:43:29,249 - stpipe.Detector1Pipeline.jump - WARNING -   readnoise_2d /= gain_2d
# 2023-12-20 17:43:29,249 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 17:43:29,625 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 74.716790
# 2023-12-20 17:43:29,631 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2023-12-20 17:43:40,201 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs1_ramp.fits
# 2023-12-20 17:43:40,297 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_ramp.fits>,).
# 2023-12-20 17:43:40,298 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2023-12-20 17:43:40,324 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0043.fits
# 2023-12-20 17:43:40,324 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0025.fits
# 2023-12-20 17:43:40,372 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2023-12-20 17:43:40,373 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# 2023-12-20 17:43:40,373 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2023-12-20 17:43:40,374 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2023-12-20 17:43:42,754 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 6
# 2023-12-20 17:48:38,125 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2023-12-20 17:48:38,418 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(32, 2048) from jw01366003001_04101_00001-seg003_nrs1_ramp.fits>,).
# 2023-12-20 17:48:38,419 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:48:38,433 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.429
# 2023-12-20 17:48:38,439 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2023-12-20 17:48:38,503 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg003_nrs1_ramp.fits>,).
# 2023-12-20 17:48:38,504 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 17:48:38,571 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.429
# 2023-12-20 17:48:38,581 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2023-12-20 17:48:38,831 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs1_rateints.fits
# 2023-12-20 17:48:38,831 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2023-12-20 17:48:38,832 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 17:48:38,874 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs1_rate.fits
# 2023-12-20 17:48:38,874 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# Run time:  24.766666666666666  min

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 3](#stage3)

# %% [markdown]
# ---
#
# ### <font color='white'>-</font>Stage 2: Spec2Pipeline <a class="anchor" id="stage2"></a>
#
# ---

# %% [markdown]
# The `Spec2Pipeline` performs additional instrumental corrections and calibrations to produce fully calibrated exposure. Details of the specific steps that need to be included for the BOTS mode are documented in the <a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_spec2.html">calwebb_spec2: Stage 2 Spectroscopic Processing.</a>
#
# Prior to running the pipeline, we will perform two modifications:
# 1. Remove 1/f noise
# 2. Modify the aperture size with which we will run the `extract_1d` step
#
# JWST detector readout electronics (a.k.a. SIDECAR ASICs) generate significant 1/f noise during detector operations and signal digitization. When using NIRSpec BOTS, this 1/f noise appears as vertical banding that spans the entire width of the 2d spectral image, and varies from column to column. If not handled properly, the 1/f noise can introduce systematic errors and extra scatter in the light curves. For more information, please visit: <a href="https://jwst-docs.stsci.edu/methods-and-roadmaps/jwst-time-series-observations/jwst-time-series-observations-noise-sources#JWSTTimeSeriesObservationsNoiseSources-1/fnoise">JWST Time-Series Observations Noise Sources.</a>
#
# At the time of writing, NSClean has been envisioned as the main 1/f-noise removal algorithm for NIRSpec in the STScI pipeline. Given this function is still under implementation, we will remove 1/f noise by subtracting the median background flux on a column-by-column basis. The function below will perform this task.

# %%
def correct_one_over_f(image, b_low, b_high, detector_id):
    # Inputs:
    # image - image to correct, 2D array
    # blow - lower column pixels for the two regions, a tuple of two values 
    # bhigh - higher column pixels for the two regions, a tuple of two values

    y_lo_1, y_lo_2 = b_low
    y_hi_1, y_hi_2 = b_high
    
    corrected_image = np.copy(image)
    for i in range(image.shape[1]):
        #print(image.shape[1])
        
        if (detector_id == 'nrs1'):
            corrected_image[:, i] = image[:, i] - np.nanmedian( np.concatenate((image[y_lo_1:y_hi_1,i],image[y_lo_2:y_hi_2,i])) )

        if (detector_id == 'nrs2'):
            if (i <= 1250):
                corrected_image[:, i] = image[:, i] - np.nanmedian( image[y_lo_1:y_hi_1,i] )
            if (i > 1250):
                corrected_image[:, i] = image[:, i] - np.nanmedian( image[y_lo_2:y_hi_2,i] )

    return corrected_image

# %% [markdown]
# We next specify the background region that the 1/f noise function will use for subtraction.

# %%
from astropy.io import fits

n_segments = len(froot)

if process_detector == 'nrs1':
    b_low  = (0, 26)
    b_high = (5, 31)

if process_detector == 'nrs2':
    b_low  = (26, 0)
    b_high = (31, 5)


for i in range(n_segments):
    print('\nRemoving 1overf noise from segment ', i+1, ' out of ', n_segments)
    ramp_HDUL = datamodels.open(stage1_dir + froot[i] + 'rateints.fits')
    #ramp_HDUL.info() # Use this command if you wish to take a look at the data model contents
    ramp_sci = ramp_HDUL.data
    
    #ramp_HDUL = fits.open(stage1_dir + froot[i] + 'rateints.fits')
    #ramp_sci = ramp_HDUL[1].data
    
    corrected_1overf_2Dspec = np.copy(ramp_sci)
    for j in range(len(ramp_sci[:,0,0])):
        corrected_1overf_2Dspec[j, :, :] = correct_one_over_f( ramp_sci[j, :, :], b_low, b_high, process_detector )
    ramp_HDUL.data = corrected_1overf_2Dspec
    ramp_HDUL.save(stage1_dir + froot[i] + 'rateints_1cl.fits') # add '1cl' suffix to indicate 1/f-cleaned 2D spectra
    #ramp_HDUL[1].data = corrected_1overf_2Dspec
    #ramp_HDUL.writeto(stage1_dir + froot[i] + 'rateints_1cl.fits', overwrite=True) # add '1cl' suffix to indicate 1/f-cleaned 2D spectra
    ramp_HDUL.close()
# Out:
# 2023-12-20 17:48:38,963 - stpipe - WARNING - /var/folders/k5/bfrtdtg92314p_l09pny5d7c0002hw/T/ipykernel_28883/1607684194.py:15: RuntimeWarning: All-NaN slice encountered
# 2023-12-20 17:48:38,963 - stpipe - WARNING -   corrected_image[:, i] = image[:, i] - np.nanmedian( np.concatenate((image[y_lo_1:y_hi_1,i],image[y_lo_2:y_hi_2,i])) )
# 2023-12-20 17:48:38,963 - stpipe - WARNING -
# Removing 1overf noise from segment  1  out of  3
# 2023-12-20 17:48:45,001 - stpipe - WARNING - /var/folders/k5/bfrtdtg92314p_l09pny5d7c0002hw/T/ipykernel_28883/1607684194.py:15: RuntimeWarning: All-NaN slice encountered
# 2023-12-20 17:48:45,001 - stpipe - WARNING -   corrected_image[:, i] = image[:, i] - np.nanmedian( np.concatenate((image[y_lo_1:y_hi_1,i],image[y_lo_2:y_hi_2,i])) )
# 2023-12-20 17:48:45,001 - stpipe - WARNING -
# Removing 1overf noise from segment  2  out of  3
# 2023-12-20 17:48:50,937 - stpipe - WARNING - /var/folders/k5/bfrtdtg92314p_l09pny5d7c0002hw/T/ipykernel_28883/1607684194.py:15: RuntimeWarning: All-NaN slice encountered
# 2023-12-20 17:48:50,938 - stpipe - WARNING -   corrected_image[:, i] = image[:, i] - np.nanmedian( np.concatenate((image[y_lo_1:y_hi_1,i],image[y_lo_2:y_hi_2,i])) )
# 2023-12-20 17:48:50,938 - stpipe - WARNING -
# Removing 1overf noise from segment  3  out of  3

# %% [markdown]
# Next, we can plot the uncorrected vs 1/f-corrected image, as well as the difference to inspect for any residuals.

# %%
if process_detector == 'nrs1':
    int_id  = 100 # select an integration to show
    f_lo = -0.5 # lower limit for flux
    f_hi = +0.5 # upper limit for flux

if process_detector == 'nrs2':
    int_id  = 0 # select an integration to show
    f_lo = -0.5 # lower limit for flux
    f_hi = +0.5 # upper limit for flux

# Plot the original uncorrected image
plt.figure(figsize=(20,8))
plt.subplot(211)
plt.title('Uncorrected 2D spectrum ' + process_detector.upper(), fontsize=20)
im1 = plt.imshow(ramp_sci[int_id,:,:], 
                 interpolation='None', 
                 aspect='auto', 
                 cmap='inferno', 
                 origin='lower',
                 clim=(f_lo, f_hi))

plt.xlabel('x-column', fontsize=15)
plt.ylabel('y-row', fontsize=15)

cb1 = plt.colorbar(label=r'Counts, DN/s')




# Plot the corrected image
plt.figure(figsize=(20,8))
plt.subplot(211)
plt.title('1/f-corrected 2D spectrum ' + process_detector.upper(), fontsize=20)
im1 = plt.imshow(corrected_1overf_2Dspec[int_id,:,:], 
                 interpolation='None', 
                 aspect='auto', 
                 cmap='inferno', 
                 origin='lower',
                 clim=(f_lo, f_hi))

plt.xlabel('x-column', fontsize=15)
plt.ylabel('y-row', fontsize=15)

cb1 = plt.colorbar(label=r'Counts, DN/s')



# Plot the difference image
plt.figure(figsize=(20,8))
plt.subplot(211)
plt.title('Difference 2D spectrum ' + process_detector.upper(), fontsize=20)
im1 = plt.imshow(ramp_sci[int_id,:,:] - corrected_1overf_2Dspec[int_id,:,:], 
                 interpolation='None', 
                 aspect='auto', 
                 cmap='inferno', 
                 origin='lower',
                 clim=(f_lo, f_hi))

plt.xlabel('x-column', fontsize=15)
plt.ylabel('y-row', fontsize=15)

cb1 = plt.colorbar(label=r'Counts, DN/s')

plt.show()

# %% [markdown]
# The correction looks good with no significant residual as shown by the difference image.
#
# Finally, we modify the parameter reference file of th `extract_1d` step to specify the width od the extraction aperture and enable other useful parameters detailed in the next cell. This and several additional parameter reference files are located in the `CRDS_PATH` directory. One can modify them "by hand" some of them, such as .json files. We opt to modify using the cell below.

# %%
import json

json_name = 'jwst_nirspec_extract1d_0006.json'
json_dir = os.environ['CRDS_PATH'] + '/references/jwst/nirspec/'

# open file in read-mode
with open(json_dir + json_name, 'r') as file:
    # read JSON data
    data = json.load(file)
    if (process_detector == 'nrs1'):
        data['apertures'][0]['extract_width'] = 6 # extraction aperture radius in pixels
        data['apertures'][0]['xstart'] = 100 # lower x-index 
    if process_detector == 'nrs2':
        data['apertures'][0]['extract_width'] = 27 # extraction aperture radius in pixels        
#    data['apertures'][0]['xstop'] = 300 # upper x-index
#    data['apertures'][0]['ystart'] = 5
#    data['apertures'][0]['ystop'] = 25
#    data['apertures'][0]['nod2_offset'] = 0 # apply no offsets
    data['apertures'][0].pop("nod2_offset") # remove
#    data['apertures'][0]['nod3_offset'] = 0
    data['apertures'][0].pop("nod3_offset") # remove
    #data['apertures'][0]['nod5_offset'] = 0
    data['apertures'][0].pop("nod5_offset") # remove
#    print(data['apertures'][0]['extract_width'])

newData = json.dumps(data, indent=4)
#print(json_name[:-5])
with open(json_dir + json_name[:-5] + '_bots.json', 'w') as file: # add the suffix '_bots' to distinguish the file from the default version.
    # write
    file.write(newData)

# %%
from jwst.pipeline import Spec2Pipeline

# %% [markdown]
# The runtime of the `Spec2` step takes approximately 6 minutes for all segments.

# %%
param_stage2 = {
    'assign_wcs'    :{'skip': False},
    'extract_2d'    :{'skip': False},
    'srctype'       :{'skip': False},
    'flat_field'    :{'skip': True}, # we opt to skip this step, because it can introduce spurious pixels that can affect the light curve scatter
    'photom'        :{'skip': True}, # we also skip this step, because BOTS exoplanet observations are relative 
    'pixel_replace' :{'skip': False, 'n_adjacent_cols': 5, 'algorithm':"fit_profile"}, #, 'algorithm':'mingrad'
    'extract_1d'    :{'skip': False, 'override_extract1d': f'{json_dir + json_name[:-5]}_bots.json', 'apply_apcorr': False, 'subtract_background': False } # 'dispaxis': 1, 'xstart': 100, 'xstop': 150, 'extract_width': 10},
}

start = tt.time()

for i in range(len(files)):
    Spec2Pipeline.call(stage1_dir + froot[i]+'rateints_1cl.fits', 
                       save_results = True, 
                       steps        = param_stage2, 
                       output_dir   = stage2_dir)

end = tt.time()
print("Run time: ", round(end-start,1)/60.0, " min")
# Out:
# 2023-12-20 17:48:57,462 - CRDS - ERROR -  Error determining best reference for 'pars-pixelreplacestep'  =   Unknown reference type 'pars-pixelreplacestep'
# 2023-12-20 17:48:57,466 - stpipe - INFO - PARS-SPEC2PIPELINE parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-spec2pipeline_0022.asdf
# 2023-12-20 17:48:57,482 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2023-12-20 17:48:57,483 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2023-12-20 17:48:57,484 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2023-12-20 17:48:57,484 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2023-12-20 17:48:57,485 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2023-12-20 17:48:57,485 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 
- stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 6.057163671155447e-05 deg
# 2023-12-20 17:48:58,080 - stpipe.Spec2Pipeline.assign_wcs - INFO - Slits projected on detector NRS1: ['S1600A1']
# 2023-12-20 17:48:58,080 - stpipe.Spec2Pipeline.assign_wcs - INFO - Computing WCS for 1 open slitlets
# 2023-12-20 17:48:58,106 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.1446726469999745 deg
# 2023-12-20 17:48:58,107 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3188409810000999 deg
# 2023-12-20 17:48:58,107 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.0005219736831524339 deg
# 2023-12-20 17:48:58,108 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 6.057163671155447e-05 deg
# 2023-12-20 17:48:58,122 - stpipe.Spec2Pipeline.assign_wcs - INFO - SPORDER= -1, wrange=[2.87e-06, 5.27e-06]
# 2023-12-20 17:48:58,204 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999036490550833
# 2023-12-20 17:48:58,230 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 1
# 2023-12-20 17:48:58,231 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 2
# 2023-12-20 17:48:58,231 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 3
# 2023-12-20 17:48:58,231 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 4
# 2023-12-20 17:48:58,231 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 1 open slits in quadrant 5
# 2023-12-20 17:48:58,360 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a NIRSPEC nrs_brightobj pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf', 'fore': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf', 'fpa': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0010.asdf', 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2023-12-20 17:48:58,475 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2023-12-20 17:48:58,487 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2023-12-20 17:48:58,547 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>, []).
# 2023-12-20 17:48:58,548 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1'}
# 2023-12-20 17:48:58,548 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2023-12-20 17:48:58,550 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2023-12-20 17:48:58,604 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>, []).
# 2023-12-20 17:48:58,605 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2023-12-20 17:48:58,605 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2023-12-20 17:48:58,607 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2023-12-20 17:48:58,660 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>,).
# 2023-12-20 17:48:58,660 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1'}
# 2023-12-20 17:48:58,661 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2023-12-20 17:48:58,663 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2023-12-20 17:48:58,715 - stpipe.Spec2Pipeline.extract_2d - INFO - Step extract_2d running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>,).
# 2023-12-20 17:48:58,716 - stpipe.Spec2Pipeline.extract_2d - INFO - Step extract_2d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': None, 'wfss_nbright': 1000}
# 2023-12-20 17:48:58,731 - stpipe.Spec2Pipeline.extract_2d - INFO - EXP_TYPE is NRS_BRIGHTOBJ
# 2023-12-20 17:48:58,821 - stpipe.Spec2Pipeline.extract_2d - INFO - Name of subarray extracted: S1600A1
# 2023-12-20 17:48:58,822 - stpipe.Spec2Pipeline.extract_2d - INFO - Subarray x-extents are: 775 2048
# 2023-12-20 17:48:58,822 - stpipe.Spec2Pipeline.extract_2d - INFO - Subarray y-extents are: 0 28
# 2023-12-20 17:48:58,983 - stpipe.Spec2Pipeline.extract_2d - INFO - set slit_attributes completed
# 2023-12-20 17:48:58,990 - stpipe.Spec2Pipeline.extract_2d - INFO - Update S_REGION to POLYGON ICRS  217.326463389 -3.444792699 217.326917709 -3.444605004 217.326744101 -3.444195992 217.326289754 -3.444383643
# 2023-12-20 17:48:58,991 - stpipe.Spec2Pipeline.extract_2d - INFO - extract_2d updated S_REGION to POLYGON ICRS  217.326463389 -3.444792699 217.326917709 -3.444605004 217.326744101 -3.444195992 217.326289754 -3.444383643
# 2023-12-20 17:48:58,996 - stpipe.Spec2Pipeline.extract_2d - INFO - Step extract_2d done
# 2023-12-20 17:48:59,061 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<SlitModel(155, 28, 1273) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>,).
# 2023-12-20 17:48:59,062 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'source_type': None}
# 2023-12-20 17:48:59,159 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_BRIGHTOBJ
# 2023-12-20 17:48:59,159 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2023-12-20 17:48:59,159 - stpipe.Spec2Pipeline.srctype - INFO - Input is a TSO exposure; setting SRCTYPE = POINT
# 2023-12-20 17:48:59,163 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2023-12-20 17:48:59,221 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step master_background_mos running with args (<SlitModel(155, 28, 1273) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>,).
# 2023-12-20 17:48:59,223 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step master_background_mos parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None, 'user_slit_loc': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}}}
# 2023-12-20 17:48:59,224 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step skipped.
# 2023-12-20 17:48:59,225 - stpipe.Spec2Pipeline.master_background_mos - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 17:48:59,225 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step master_background_mos done
# 2023-12-20 17:48:59,282 - stpipe.Spec2Pipeline.wavecorr - INFO - Step wavecorr running with args (<SlitModel(155, 28, 1273) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>,).
# 2023-12-20 17:48:59,283 - stpipe.Spec2Pipeline.wavecorr - INFO - Step wavecorr parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1'}
# 2023-12-20 17:48:59,467 - stpipe.Spec2Pipeline.wavecorr - INFO - Using WAVECORR reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavecorr_0003.asdf
# 2023-12-20 17:48:59,567 - stpipe.Spec2Pipeline.wavecorr - INFO - Detected a POINT source type in slit S1600A1
# 2023-12-20 17:48:59,568 - stpipe.Spec2Pipeline.wavecorr - INFO - slit name S1600A1
# 2023-12-20 17:48:59,568 - stpipe.Spec2Pipeline.wavecorr - INFO - xoffset, yoffset, 6.03933060849859e-13, -6.0457443092806e-13
# 2023-12-20 17:48:59,579 - stpipe.Spec2Pipeline.wavecorr - INFO - Source X/Y position in the slit: -0.011585206334868, -0.03203498317654394
# 2023-12-20 17:48:59,649 - stpipe.Spec2Pipeline.wavecorr - INFO - Using wavelength zero-point correction for aperture S1600A1
# 2023-12-20 17:48:59,656 - stpipe.Spec2Pipeline.wavecorr - INFO - Step wavecorr done
# 2023-12-20 17:48:59,726 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<SlitModel(155, 28, 1273) from jw01366003001_04101_00001-seg001_nrs1_rateints_1cl.fits>,).
# 2023-12-20 17:48:59,727 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 
INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/jw01366003001_04101_00001-seg003_nrs1_rateints_1cl_x1dints.fits
# 2023-12-20 17:53:29,796 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-12-20 17:53:29,797 - stpipe.Spec2Pipeline - INFO - Finished processing product /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs1_rateints_1cl
# 2023-12-20 17:53:29,802 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2023-12-20 17:53:29,803 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 17:53:30,095 - stpipe.Spec2Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/jw01366003001_04101_00001-seg003_nrs1_rateints_1cl_calints.fits
# 2023-12-20 17:53:30,096 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# Run time:  4.545  min

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Spec2](#stage2)

# %% [markdown]
# Plot a few of the extracted spectra for a visual inspection.

# %%
x1d = datamodels.open(stage2_dir + froot[0] + 'rateints_1cl_x1dints.fits')

#x1d.info(max_rows=None) # prints the full contents
x1d.info(max_rows=10)
#print(x1d)

# Obtain the wavelength and flux from 1d spectral products 
x1d_wave = x1d.spec[0].spec_table.WAVELENGTH
x1d_flux = x1d.spec[0].spec_table.FLUX


wave_um   = x1d_wave
all_times = x1d.int_times.int_mid_BJD_TDB
#print(len(all_times))

n_spec = len(x1d.spec)
n_pix  = len(x1d.spec[0].spec_table.FLUX)
#print(n_spec)
# Out:
# root (AsdfObject)
# ├─asdf_library (Software)
# │ ├─author (str): The ASDF Developers
# │ └─3 not shown
# ├─history (dict) ...
# ├─_fits_hash (str): ad5c155cfea7d1137d2591db642c80e5b4ce4a2a696c5a73fe99506bce236183
# ├─int_times (FITS_rec): shape=(155,), dtype=void416
# ├─meta (dict) ...
# └─spec (list) ...
# Some nodes not shown.

# %% [markdown]
# Next, we will load all of the extracted spectra and time stamps in one big array for easier analysis and plotting.

# %%
# Obtain all spectra for the list of segments
for i in (range(len(froot))):
    print("Processing segment: ", i+1, ' out of ', len(froot), ': ', froot[i] + 'rateints_1cl_x1dints.fits')
    x1d = datamodels.open(stage2_dir + froot[i] + 'rateints_1cl_x1dints.fits')
    
    n_spec = len(x1d.spec)
    n_pix  = len(x1d.spec[i].spec_table.FLUX)

    seg_spec_1D   = np.zeros([n_spec, n_pix])

    for j in range(len(x1d.spec)):
        seg_spec_1D[j,:]   = x1d.spec[j].spec_table.FLUX
    
    if i == 0:
        all_spec_1D = seg_spec_1D
        all_times   = x1d.int_times.int_mid_BJD_TDB
    if i > 0:
        all_spec_1D = np.concatenate((all_spec_1D, seg_spec_1D), axis = 0)
        all_times = np.concatenate((all_times, x1d.int_times.int_mid_BJD_TDB), axis = 0)
    

print(' ')
print('Total number of time stamps: ', len(all_times))
print('Total number of 1D spectra:  ', len(all_spec_1D[:,0]))
print(' ')
print('Total number of columns: ', len(all_spec_1D[0,:]))
print('Total length of wavemap: ', len(wave_um))
print(' ')

# We will also trim several columns at the start and end of the spectra. These belong to the reference pixels and are marked 'nan'.
print('Trimming first/last 5 refeerence pixels with nan-values ...')
all_spec_1D = all_spec_1D[:,5:-5]
wave_um  = wave_um[5:-5]
# Out:
# Processing segment:  1  out of  3 :  jw01366003001_04101_00001-seg001_nrs1_rateints_1cl_x1dints.fits
# Processing segment:  2  out of  3 :  jw01366003001_04101_00001-seg002_nrs1_rateints_1cl_x1dints.fits
# Processing segment:  3  out of  3 :  jw01366003001_04101_00001-seg003_nrs1_rateints_1cl_x1dints.fits
#
# Total number of time stamps:  465
# Total number of 1D spectra:   465
#
# Total number of columns:  1173
# Total length of wavemap:  1173
#
# Trimming first/last 5 refeerence pixels with nan-values ...

# %%
# Plot three spectra from the time series with a constant offset for clarity

fig = plt.figure(figsize=(14, 8))
#plt.plot(x1d_nrs1_wave, x1d_nrs1_flux)
plt.plot(wave_um, all_spec_1D[0,:]-0.0)
plt.plot(wave_um, all_spec_1D[10,:]-70.0)
plt.plot(wave_um, all_spec_1D[100,:]-140.0)

plt.xlabel('Wavelength (microns)')
#plt.yscale('log')
plt.ylabel('Flux (Jy) + Constant offset')

if (process_detector == 'nrs1'):
    plt.xlim(2.8,3.8)
if (process_detector == 'nrs2'):
    plt.xlim(3.8,5.2)
#plt.ylim(-0.01,0.04)
plt.grid(True)
plt.show()

# %% [markdown]
# Next, we obtain a white light curve by taking the total flux between column 20 and the last column minus 20, and plot the result along with the light curve scatter, measured using the first ~100 data points.

# %%
n_spec = len(all_times)

# Obtain white light curve
wlc_flux = np.zeros(n_spec)

for i in range(n_spec):
    if (process_detector == 'nrs1'):
        wlc_flux[i] = np.nansum(all_spec_1D[i,20:-20])
    if (process_detector == 'nrs2'):
        wlc_flux[i] = np.nansum(all_spec_1D[i,5:-5])

# Normalize by the median flux of the first twenty points
wlc_flux /= np.median(wlc_flux[0:20])

# Plot
plt.figure(figsize=(12, 5))
sigma_wlc = np.sqrt(np.nanvar(wlc_flux[2:100]))
plt.plot((all_times-np.nanmean(all_times))*24., wlc_flux, color='red', marker="o", markersize=2, label=f'White light curve, (r.m.s.={round(sigma_wlc*1e6, 0)} ppm)')
plt.legend(loc='lower right')
plt.title('White Light Curve for ' + process_detector.upper() + f', $\lambda=${round(wave_um[20], 4)} - {round(wave_um[-20], 4)} $\mu$m', fontsize=15)
plt.xlabel('Time since mid-exposure, hr', fontsize=15)
plt.ylabel('Normalized flux', fontsize=15)
#plt.xlim([1, nintegrations])
if (process_detector == 'nrs1'):
    plt.ylim([0.965,1.003])
if (process_detector == 'nrs2'):
    plt.ylim([0.965,1.015])
#plt.xlim([-4.2,-0.5])

plt.show()

print('White Light Curve scatter (ppm):  ', round(sigma_wlc*1e6, 0))
# Out:
# White Light Curve scatter (ppm):   230.0

# %% [markdown]
# The white light curve shows relatively low scatter (230 and 548 ppm for NRS1 and NRS2, respectively) and exhibits the morphology of a transit event along with a step-function flux jump near the mid-transit. This flux jump (a decrease of flux in this case) is attributed to a 'tilt' event, associated with one of the segments of the JWST mirror. A 'tilt' event is considered any uncommanded change in the tip tilt orientation of a mirror segment, and can be caused by a micrometeorite impact. For further details, please consult the following page: <a href="https://jwst-docs.stsci.edu/methods-and-roadmaps/jwst-time-series-observations/jwst-time-series-observations-noise-sources">JWST TSO noise sources.</a>

# %%
lc_map = np.copy(all_spec_1D)
# 
spec_xlen = len(lc_map[0,:])


correct_tilt_event = 'yes'

for j in range(spec_xlen):
    # Normalize with each spectral line (removes throughput)
    lc_map[:,j] /= np.nanmean(lc_map[0:170,j])
    if correct_tilt_event == 'yes':
        # Correct for tilt event
        lc_map[270:,j] /= np.nanmean(lc_map[330:460,j])


mfactor = 1.6
plt.figure(figsize=(5*mfactor,8*mfactor))
plt.subplot(211)
plt.title('Spectroscopic light curves for ' + process_detector.upper(), fontsize=15)
im1 = plt.imshow(lc_map, 
                 interpolation='bilinear', 
                 aspect='auto', 
                 cmap='inferno_r', 
                 origin='lower', clim=(0.977, 1.005 ))

#plt.xlabel(r'Wavelength, $\mu$m', fontsize=15)
plt.xlabel(r'x-column, pixel', fontsize=15)
plt.ylabel('Integration ', fontsize=15)

# Suppress axis
#plt.axis('off')

#plt.axes()
#secax = axes().secondary_yaxis('right', functions=(RPRS_TO_H, H_TO_RPRS))
#secax.set_ylabel('Pressure scale height')

cb1 = plt.colorbar(label=r'Normalized Flux')

plt.show()

# %% [markdown]
# The plot above shows all extracted 1d spectra covering the transit event. The horizontal axis is the spectral direction (wavelength) and the vertical - each integration (time). The dark pixels correspond to the out-of-transit data (pre/post transit), the orange horizontal stripes indicate the ingress and egress portions, and the yellow stripe shows the in-transit part of the light curve. Please note, we have corrected the tilt event data by normalizing all spectra after integration 330 using the post transit flux.
#
# We now have white and spectroscopic light curves, which are ready for fitting (not covered in this notebook). In case there is a need to identify spectral trace and obtain centroid information for the time series, please consult the following notebook that offers workaround solutions for Spec2 with additional analysis and features, presented on a JWebbinar in December 2023: <a href="https://github.com/exonik/JWebbinar2023-TSO/blob/main/Part2-Spec2.ipynb">Part2-Spec2.ipynb</a>
#
# It should be pointed out that the workaround solutions lead to a lower white light curve scatter for this particular data set (approximately 70 ppm lower, or 160ppm for NRS1). The difference is determined by two factors:
# 1. The pixel replacement step in the workaround makes use of a nominal psf profile constructed from adjacent columns (of a column that needs to be corrected) to identify high and low pixels in addition to the data quality flags, and
# 2. At the time of writing the spectral resampling step is unavailalbe in the STScI pipeline. Instead, in the workaround notebook, we fit for the centroid of the star to locate and trace the spectra (without resampling) and perform aperture extraction using the trace.
#
# The rest of this notebook demonstrates how to rerun the third and final stage of the STScI pipeline, which extracts the spectra (yes, again) and produces a white light curve, which we already did.

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 2](#stage2)

# %% [markdown]
# ---
# ### <font color='white'>-</font>Stage 3: Tso3Pipeline<a class="anchor" id="stage3"></a>
#
# ---
#
# The stage3 TSO pipeline is applied to associations (`.json` files) of calibrated BOTS exposures and produces calibrated spectra and white light curve of the source object. For details, please consult  <a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_tso3.html">calwebb_tso3: Stage 3 Time-Series Observation(TSO) Processing.</a>
#
# To be able to run the `TSO3Pipeline`, we need to modify the association file to have only the science exposures of the detector we analyze. We need to exclude the target acquisition exposures (TAs) from the members of the association. The next cell performs this task.

# %%
# open file in read-mode
with open(stage2_dir + asn_spec3_file, 'r') as file:
    # read JSON data
    data = json.load(file)

# Print json contents to screen
#print(json.dumps(data, indent=2))

#print(data['products'][0]['members'][0]['expname'])
#print(len(data['products'][0]['members']))

#idx = []

for i in range(len(data['products'][0]['members'])):
    
    # Print to screen identify the correct member
    #print(data['products'][0]['members'][i]['exptype'])
    #print(data['products'][0]['members'][i]['expname'][0:38]+'rateints_1cl_calints.fits')

    # Rename the members to match the filenames of the 1/f - corrected files 
    data['products'][0]['members'][i]['expname'] = data['products'][0]['members'][i]['expname'][0:38]+'rateints_1cl_calints.fits'
    #print(data['products'][0]['members'][i]['expname'])

    # Identify the indexes of the target acquisition exposures
    #if (data['products'][0]['members'][i]['exptype'] == 'target_acquisition'):
        #idx.append(i) 
        #print(data['products'][0]['members'][i])

# Print the ideces to screen and remove the entries from the association 
#print(idx)
#del data['products'][0]['members'][idx[0]-1]
#del data['products'][0]['members'][idx[1]-1]




# Delete file names that are not needed e.g., TA exposures.
if (process_detector == 'nrs1'):
    del data['products'][0]['members'][7]
    del data['products'][0]['members'][6]
    del data['products'][0]['members'][5]
    del data['products'][0]['members'][3]
    del data['products'][0]['members'][1]

if (process_detector == 'nrs2'):
    del data['products'][0]['members'][7]
    del data['products'][0]['members'][6]
    del data['products'][0]['members'][4]
    del data['products'][0]['members'][2]
    del data['products'][0]['members'][0]

 




# Save the modified association as a new file
newData = json.dumps(data, indent=4)
with open(stage2_dir + asn_spec3_file[:-5] + '_'+process_detector+'.json', 'w') as file: # add the suffix '_bots' to distinguish the file from the default version.
    # write
    file.write(newData)

# %% [markdown]
# We will once again modify the `extract_1d` parameter reference file to adjust the size of extracting aperture. This is needed, because the pipeline currently does not resample the 2D spectra to rectify the spactra (remove the curvature). We therefore rely on a wide extraction aperture and provide the 1/f-noise corrected 2D spectra.

# %%
import json

json_name = 'jwst_nirspec_extract1d_0006.json'
json_dir = os.environ['CRDS_PATH'] + '/references/jwst/nirspec/'

# open file in read-mode
with open(json_dir + json_name, 'r') as file:
    # read JSON data
    data = json.load(file)
    if (process_detector == 'nrs1'):
        data['apertures'][0]['extract_width'] = 6 # extraction aperture radius in pixels
        data['apertures'][0]['xstart'] = 100 # lower x-index 
    if process_detector == 'nrs2':
        data['apertures'][0]['extract_width'] = 27 # extraction aperture radius in pixels        
#    data['apertures'][0]['xstop'] = 300 # upper x-index
#    data['apertures'][0]['ystart'] = 5
#    data['apertures'][0]['ystop'] = 25
#    data['apertures'][0]['nod2_offset'] = 0 # apply no offsets
    data['apertures'][0].pop("nod2_offset") # remove
#    data['apertures'][0]['nod3_offset'] = 0
    data['apertures'][0].pop("nod3_offset") # remove
    #data['apertures'][0]['nod5_offset'] = 0
    data['apertures'][0].pop("nod5_offset") # remove
#    print(data['apertures'][0]['extract_width'])

newData = json.dumps(data, indent=4)
#print(json_name[:-5])
with open(json_dir + json_name[:-5] + '_bots.json', 'w') as file: # add the suffix '_bots' to distinguish the file from the default version.
    # write
    file.write(newData)

# %%
from jwst.pipeline import Tso3Pipeline

# %% [markdown]
# We opt to skip the `outlier_detection` step, because it causes too many improper detections and corrections, especially in the ingress/egress parts of the transit light curve. In addition, the pipeline documentation suggests to run again the `extract_1d` step before producing the white light curve. This can be skipped as well, as long as we provide the correct directory with extracted spectra from `stage 2`. In that case, `stage 3` should take much less runtime to complete.

# %%
param_stage3 = {
    'outlier_detection' :{'skip': True},
    'extract_1d'        :{'skip': False, 'override_extract1d': f'{json_dir + json_name[:-5]}_bots.json', 'apply_apcorr': False, 'subtract_background': False }, # 'dispaxis': 1, 'xstart': 100, 'xstop': 150, 'extract_width': 10},
    'white_light'       :{'skip': False}
}


start = tt.time()

Tso3Pipeline.call(stage2_dir + asn_spec3_file[:-5] + '_'+process_detector+'.json', 
                  save_results = True, 
                  steps        = param_stage3, 
                  output_dir   = stage3_dir)

end = tt.time()
print("Run time: ", round(end-start,1)/60.0, " min")
# Out:
# 2023-12-20 17:53:43,293 - CRDS - ERROR -  Error determining best reference for 'pars-whitelightstep'  =   No match found.
# 2023-12-20 17:53:43,297 - stpipe.Tso3Pipeline - INFO - Tso3Pipeline instance created.
# 2023-12-20 17:53:43,298 - stpipe.Tso3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2023-12-20 17:53:43,299 - stpipe.Tso3Pipeline.tso_photometry - INFO - TSOPhotometryStep instance created.
# 2023-12-20 17:53:43,300 - stpipe.Tso3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2023-12-20 17:53:43,301 - stpipe.Tso3Pipeline.photom - INFO - PhotomStep instance created.
# 2023-12-20 17:53:43,301 - stpipe.Tso3Pipeline.white_light - INFO - WhiteLightStep instance created.
# 2023-12-20 17:53:43,471 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline running with args ('/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/jw01366-o003_20230901t213306_tso3_00001_asn_nrs1.json',).
# 2023-12-20 17:53:43,474 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'scale_detection': False, 'steps': {'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'tso_photometry': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalog': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': False, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': False, 'ifu_autocen': False, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}, 'white_light': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.ecsv', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'whtlt', 'search_output_file': True, 'input_dir': '', 'min_wavelength': None, 'max_wavelength': None}}}
# 2023-12-20 17:53:43,686 - stpipe.Tso3Pipeline - INFO - Prefetching reference files for dataset: 'jw01366003001_04101_00001-seg001_nrs1_rateints_1cl_calints.fits' reftypes = ['gain', 'readnoise']
# 2023-12-20 17:53:43,689 - stpipe.Tso3Pipeline - INFO - Prefetch for GAIN reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0025.fits'.
# 2023-12-20 17:53:43,689 - stpipe.Tso3Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_
# Run time:  2.271666666666667  min

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 2](#stage2), [Link to Stage 3](#stage3)

# %% [markdown]
# Read and plot the white light curve from the `.csv` file

# %%
# Read the white light curve as an Astropy table
schema = {'data': '2D float64'}

data = Table.read(stage3_dir + 'jw01366-o003_t001_nirspec_f290lp-g395h-s1600a1-sub2048_whtlt.ecsv', format='ascii.ecsv', converters=schema)

tx = data['MJD']
ty = data['whitelight_flux']

xx = np.zeros(len(tx))
yy = np.zeros(len(tx))

for i in range(len(tx)):
    xx[i] = tx[i]
    yy[i] = ty[i]
    #print(tx[i])

yy = yy/np.median(yy[0:100])

print('sigma: ', np.std(yy[2:100])*1e6)



plt.figure(figsize=(12, 5))
sigma_wlc = np.sqrt(np.nanvar(yy[2:100]))
plt.plot((xx-np.nanmean(xx))*24., yy, color='blue', marker="o", markersize=2, label=f'White light curve, (r.m.s.={round(sigma_wlc*1e6, 0)} ppm)')
plt.legend(loc='lower right')
plt.title('White Light Curve for ' + process_detector.upper(), fontsize=15)
plt.xlabel('Time since mid-exposure, hr', fontsize=15)
plt.ylabel('Normalized flux', fontsize=15)
#plt.xlim([1, nintegrations])
if (process_detector == 'nrs1'):
    plt.ylim([0.965,1.003])
if (process_detector == 'nrs2'):
    plt.ylim([0.965,1.015])
#plt.xlim([-4.2,-0.5])

plt.show()

print('White Light Curve scatter (ppm):  ', round(sigma_wlc*1e6, 0))
# Out:
# sigma:  229.15670343248044
# White Light Curve scatter (ppm):   229.0

# %% [markdown]
# ---
#
# ### <font color='white'>-</font>5. Concluding remarks<a class="anchor" id="remarks"></a>
#
# ---

# %% [markdown]
# In this notebook, we demonstrated how to obtain white and spectroscopic light curves by (re-) running the three stages of the JWST pipeline and our custom steps. The saved data producs can now be provided to light curve fitting codes for measurements of the physical properties of the exoplanet (or other source with temporal variability) and obtaining a transmission spectrum. It should be pointed out that the analyses performed here are only a subset of the possible analyses one can perform, and are in no way the final word on _how_ JWST data _should_ be analyzed. This will be solidified more and more as data comes and best practices are established in the current and future cycles.
#
# In conclusion, I would like to express my gratitude to the entire JWST team that has supported the creation of this notebook through discussions and testing, which have improved the notebook. In particular, special thanks to the Time-Series Observations Working Group at STScI, including Néstor Espinoza, Leonardo Ubeda, Sarah Kendrew, Elena Manjavacas, Brian Brooks, Mike Reagan, Loïc Albert, Everett Schlawin, Stephan Birkmann among others. To the NIRCam IDT team for multiple fruitful discussions, including Everett Schlawin, Thomas Beatty, Tom Greene and Jarron Leisenring. To the ERS Transiting Exoplanet team who have provided several venues for discussion and community input. To the several JWST team members, including behind the pipeline and the mission itself, including and in no particular order Bryan Hilbert, Armin Rest, Anton Koekemoer, Alicia Canipe, Melanie Clarke, James Muzerolle, Kayli Glidic, Jeff Valenti and Karl Gordon.

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 2](#stage2), [Link to Stage 3](#stage3)
