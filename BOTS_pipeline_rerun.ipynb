# %% [markdown]
# <img style="float: center;" src='https://github.com/STScI-MIRI/MRS-ExampleNB/raw/main/assets/banner1.png' alt="stsci_logo" width="1000px"/><br>
#
# ----
# # NIRSpec BOTS pipeline rerun
# ----
#
# **Author**: Nikolay Nikolov, AURA Associate Scientist, NIRSpec branch
# <br>
# **Pipeline Version**: 1.12.5 on December 19, 2023
# <br>
# **Last Update**: December 18, 2023

# %% [markdown]
# ## <font color='white'>-</font>Table of contents<a class="anchor" id="table"></a>
# 1. [Introduction and setup](#intro)<br>
# 2. [Data download](#download)<br>
# 3. [Stage 1: Detector1Pipeline](#stage1)<br>
# 4. [Stage 2: Spec2Pipeline](#stage2)<br>
# 5. [Stage 3: Tso3Pipeline](#stage3)<br>
# 6. [Concluding remarks](#remarks)<br>

# %% [markdown]
# ---
#
# ### 1.<font color='white'>-</font>Introduction and setup<a class="anchor" id="intro"></a>
#
# ---
#
# The purpose of this notebook is to demonstrate how to run the three stages of the STScI pipeline for NIRSpec BOTS. At the time of creating this notebook the pipeline continues to require further imporvement. In order to deliver useful products for light curve fitting, this notebook offests work around solutions instead of making use of direct pipeline products. Prior to performing data analysis, we import all the needed libraries and set up paths.

# %%
# General functions
import os
import time as tt
import pickle
import cv2
import tqdm
import shutil

import numpy as np

# Multiprocessing functions
import multiprocessing as mp


# Astroquerry
import astroquery
from astroquery.mast import Observations

# JWST Pipeline
import jwst
import crds
from jwst import datamodels
from jwst.pipeline import Detector1Pipeline
from jwst.pipeline import Spec2Pipeline
from jwst.pipeline import Tso3Pipeline
from jwst.assign_wcs import nirspec

# Plot functions
import matplotlib.pyplot as plt

import pandas as pd
from astropy.table import Table

#%set_env CRDS_PATH /path/to/my/folder/
#%set_env CRDS_SERVER_URL https://jwst-crds.stsci.edu

print("JWST Calibration Pipeline Version={}".format(jwst.__version__))
print("Current Operational CRDS Context = {}".format(crds.get_default_context()))
print("Number of processors: ", mp.cpu_count())
# Out:
# JWST Calibration Pipeline Version=1.12.5
# Current Operational CRDS Context = jwst_1177.pmap
# Number of processors:  12

# %% [markdown]
# #### [Link to the Table of contents](#table)

# %% [markdown]
# ---
#
# ### 2.<font color='white'>-</font>Data download <a class="anchor" id="download"></a>
#
# ---
#
# The input data for this notebook is a transit of WASP-39b, observed in the BOTS G395H grism. The data set belongs to the <a href="https://www.stsci.edu/jwst/science-execution/approved-programs/dd-ers/program-1366">JWST Early Release Science program ERS-1366,</a> observation 3, and includes 456 integrations of 70 groups each with the SUB2048 subarray (array size of 2048 by 32 pixels per integration, per group), covering a total of 10.56 hours. The data set consists of three segments of `uncal` files, each with a size of 1.42 GB.
#
# Information of existing and planned JWST TSO programs of transiting exoplanets, including with the NIRSpec BOTS mode, can be obtained from <a href="https://www.stsci.edu/~nnikolov/TrExoLiSTS/JWST/trexolists.html">TrExoLiSTS</a>

# %%
process_detector = 'nrs2' # choose 'nrs1', 'nrs2'

# Define the rateints files (aka slope or rate images)
if process_detector == 'nrs1':
    files = ['jw01366003001_04101_00001-seg001_nrs1_uncal.fits',
             'jw01366003001_04101_00001-seg002_nrs1_uncal.fits',
             'jw01366003001_04101_00001-seg003_nrs1_uncal.fits']

if process_detector == 'nrs2':
    files = ['jw01366003001_04101_00001-seg001_nrs2_uncal.fits', 
             'jw01366003001_04101_00001-seg002_nrs2_uncal.fits',
             'jw01366003001_04101_00001-seg003_nrs2_uncal.fits']

asn_spec3_file = 'jw01366-o003_20230901t213306_tso3_00001_asn.json'

# %%
# Extract rootnames. We will use these to determine which file names to be analyzed
froot = [files[i].replace('uncal.fits', '') for i in range(len(files))]
print(froot)
# Out:
# ['jw01366003001_04101_00001-seg001_nrs2_', 'jw01366003001_04101_00001-seg002_nrs2_', 'jw01366003001_04101_00001-seg003_nrs2_']

# %% [markdown]
# Next, the notebook will create folder structure for the data and pipeline products from the three stages. When the notebook is run for the first time, it will also download the data and put it in the  data directory. Data download will be skipped, if the data directory with files exists.

# %%
working_dir = os.getcwd()+'/'

data_dir   = working_dir + 'data/'
stage1_dir = working_dir + 'stage1/'
stage2_dir = working_dir + 'stage2/'
stage3_dir = working_dir + 'stage3/'

    
if not os.path.exists(data_dir):
    print('Creating ' + data_dir + ' ...')
    os.makedirs(data_dir)

if not os.path.exists(stage1_dir):
    print('Creating ' + stage1_dir + ' ...')
    os.makedirs(stage1_dir)

if not os.path.exists(stage2_dir):
    print('Creating ' + stage2_dir + ' ...')
    os.makedirs(stage2_dir)

if not os.path.exists(stage3_dir):
    print('Creating ' + stage3_dir + ' ...')
    os.makedirs(stage3_dir)


# Download the uncal files, if not currently present
mast_dir = 'mast:jwst/product'
for i in range(len(files)):
    if os.path.isfile(data_dir+files[i]):
        print('Uncal files found in the data directory. Not downloading ...')
    if not os.path.isfile(data_dir+files[i]):
        print('Uncal files missing in the data directory. Now downloading ...')
        mast_path  = os.path.join(mast_dir, files[i])
        local_path = os.path.join(data_dir, files[i])
        Observations.download_file(mast_path, cache=False)
        shutil.move(working_dir+files[i], data_dir)

if not os.path.isfile(stage2_dir+asn_spec3_file):
    print('TSO3 association file is missing in the stage2 directory. Now downloading ...')
    mast_path  = os.path.join(mast_dir, asn_spec3_file)
    local_path = os.path.join(stage2_dir, asn_spec3_file)
    Observations.download_file(mast_path, cache=False)
    shutil.move(working_dir+asn_spec3_file, stage2_dir)
# Out:
# Uncal files found in the data directory. Not downloading ...
# Uncal files found in the data directory. Not downloading ...
# Uncal files found in the data directory. Not downloading ...
# TSO3 association file is missing in the stage2 directory. Now downloading ...
# Downloading URL https://mast.stsci.edu/api/v0.1/Download/file?uri=mast:jwst/product/jw01366-o003_20230901t213306_tso3_00001_asn.json to /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/jw01366-o003_20230901t213306_tso3_00001_asn.json ... [Done]

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Data download](#download), [Link to Stage2](#stage2), [Link to Stage3](#stage3)

# %% [markdown]
# ---
# ### <font color='white'>-</font>Stage 1: Detector1Pipeline<a class="anchor" id="stage1"></a>
#
# ---

# %% [markdown]
# This step applies basic detector-level corrections to all exposure types, and it is seldom refered as 'ramps-to-slopes' processing. For more information regarding the individual steps applied on NIRSpec BOTS data, please consult: <a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_detector1.html">calwebb_detector1: Stage 1 Detector Processing.</a>
#
#
# First, define a dictionary with all steps needed for BOTS, and include parameters accordingly. To perform or skip a step in the pipeline, one specifies the attribute `skip` in the parameter dictionary and assigns a value `False` for executing, or `True` for skipping the step.
#
# This step takes approximately 20 minutes for the three segments.

# %%
from jwst.pipeline import Detector1Pipeline

# %%
param_stage1 = {
    'group_scale'     :{'skip': False}, # not relevant for BOTS
    'dq_init'         :{'skip': False},
    'saturation'      :{'skip': False},
    'superbias'       :{'skip': False},
    'refpix'          :{'skip': False, 'odd_even_rows': True},
    'linearity'       :{'skip': False},
    'dark_current'    :{'skip': False},
    'jump'            :{'skip': False, 'maximum_cores': 'half', 'rejection_threshold': 4.0},    # options for maximum cores: an integer, ‘all’, ‘half’ or ‘quarter’
    'ramp_fit'        :{'skip': False, 'maximum_cores': 'half'},
    'gain_scale'      :{'skip': False} # not relevant for BOTS
}

start = tt.time()

for i in range(len(files)):
    Detector1Pipeline.call(data_dir + files[i], 
                           save_results = True, 
                           steps        = param_stage1, 
                           output_dir   = stage1_dir)

end = tt.time()
print("Run time: ", round(end-start,1)/60.0, " min")
# Out:
# 2023-12-20 13:23:47,382 - CRDS - ERROR -  Error determining best reference for 'pars-chargemigrationstep'  =   Unknown reference type 'pars-chargemigrationstep'
# 2023-12-20 13:23:47,384 - stpipe - INFO - PARS-JUMPSTEP parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-jumpstep_0002.asdf
# 2023-12-20 13:23:47,393 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-detector1pipeline_0003.asdf
# 2023-12-20 13:23:47,406 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2023-12-20 13:23:47,407 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2023-12-20 13:23:47,407 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2023-12-20 13:23:47,408 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2023-12-20 13:23:47,409 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2023-12-20 13:23:47,410 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2023-12-20 13:23:47,411 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2023-12-20 13:23:47,412 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2023-12-20 13:23:47,412 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2023-12-20 13:23:47,413 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2023-12-20 13:23:47,414 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2023-12-20 13:23:47,415 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2023-12-20 13:23:47,416 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2023-12-20 13:23:47,416 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2023-12-20 13:23:47,417 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2023-12-20 13:23:47,418 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2023-12-20 13:23:47,419 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2023-12-20 13:23:47,420 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2023-12-20 13:23:47,961 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data/jw01366003001_04101_00001-seg001_nrs2_uncal.fits',).
# 2023-12-20 13:23:47,968 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': True, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_us ...
# 2023-12-20 13:23:48,963 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01366003001_04101_00001-seg001_nrs2_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'saturation', 'superbias']
# 2023-12-20 13:23:48,979 - CRDS - INFO -  Fetching  /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0218.fits    5.8 M bytes  (1 / 1 files) (0 / 5.8 M bytes)
# 2023-12-20 13:23:56,170 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0218.fits'.
# 2023-12-20 13:23:56,171 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits'.
# 2023-12-20 13:23:56,171 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0023.fits'.
# 2023-12-20 13:23:56,172 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0049.fits'.
# 2023-12-20 13:23:56,172 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits'.
# 2023-12-20 13:23:56,173 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2023-12-20 13:23:56,173 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# 2023-12-20 13:23:56,174 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0029.fits'.
# 2023-12-20 13:23:56,174 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0429.fits'.
# 2023-12-20 13:23:56,229 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2023-12-20 13:23:59,159 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:23:59,160 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:24:00,785 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2023-12-20 13:24:00,786 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2023-12-20 13:24:00,788 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2023-12-20 13:24:01,534 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:24:01,535 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:24:01,554 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0049.fits
# 2023-12-20 13:24:03,266 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2023-12-20 13:24:04,392 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2023-12-20 13:24:05,086 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:24:05,087 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'n_pix_grow_sat': 1}
# 2023-12-20 13:24:05,105 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0029.fits
# 2023-12-20 13:24:06,720 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2023-12-20 13:24:23,609 - stpipe.Detector1Pipeline.saturation - INFO - Detected 791 saturated pixels
# 2023-12-20 13:24:23,839 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2023-12-20 13:24:23,845 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2023-12-20 13:24:24,520 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:24:24,521 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:24:24,522 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2023-12-20 13:24:24,524 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2023-12-20 13:24:24,984 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:24:24,985 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:24:25,006 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0429.fits
# 2023-12-20 13:24:26,847 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2023-12-20 13:24:27,535 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:24:27,535 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}
# 2023-12-20 13:24:29,157 - stpipe.Detector1Pipeline.refpix - INFO - NIR subarray data
# 2023-12-20 13:24:29,159 - stpipe.Detector1Pipeline.refpix - INFO - Single readout amplifier used
# 2023-12-20 13:24:29,159 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2023-12-20 13:24:29,159 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2023-12-20 13:24:29,159 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2023-12-20 13:24:29,160 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2023-12-20 13:24:29,160 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2023-12-20 13:24:29,160 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.0
# 2023-12-20 13:24:29,160 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = False
# 2023-12-20 13:25:01,118 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2023-12-20 13:25:01,807 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:25:01,808 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:25:01,826 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0023.fits
# 2023-12-20 13:25:01,860 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-12-20 13:25:05,067 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2023-12-20 13:25:05,761 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:25:05,762 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'dark_output': None}
# 2023-12-20 13:25:05,782 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0218.fits
# 2023-12-20 13:25:05,818 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=155, ngroups=70, nframes=1, groupgap=0
# 2023-12-20 13:25:05,818 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=10, nframes=1, groupgap=0
# 2023-12-20 13:25:05,819 - stpipe.Detector1Pipeline.dark_current - WARNING - Not enough data in dark reference file to match to science data.
# 2023-12-20 13:25:05,819 - stpipe.Detector1Pipeline.dark_current - WARNING - Input will be returned without subtracting dark current.
# 2023-12-20 13:25:07,663 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2023-12-20 13:25:08,143 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:25:08,144 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'signal_threshold': 25000.0}
# 2023-12-20 13:25:08,144 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2023-12-20 13:25:08,147 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration done
# 2023-12-20 13:25:08,616 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_uncal.fits>,).
# 2023-12-20 13:25:08,617 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 1000, 'after_jump_flag_time1': 90, 'after_jump_flag_dn2': 0, 'after_jump_flag_time2': 0, 'expand_large_events': False, 'min_sat_area': 1, 'min_jump_area': 5, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'edge_size': 25, 'find_showers': False, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200, 'minimum_groups': 3, 'minimum_sigclip_groups': 100, 'only_use_ints': True}
# 2023-12-20 13:25:08,626 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2023-12-20 13:25:08,626 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2023-12-20 13:25:08,637 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits
# 2023-12-20 13:25:08,672 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits
# 2023-12-20 13:25:10,203 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# 2023-12-20 13:25:10,204 - stpipe.Detector1Pipeline.jump - INFO - Extracting readnoise subarray to match science data
# 2023-12-20 13:25:10,451 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2023-12-20 13:25:11,288 - stpipe.Detector1Pipeline.jump - INFO - Creating 6 processes for jump detection
# 2023-12-20 13:26:19,668 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 69.2163 sec
# 2023-12-20 13:26:20,839 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:405: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 13:26:20,840 - stpipe.Detector1Pipeline.jump - WARNING -   data /= gain_2d
# 2023-12-20 13:26:20,840 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 13:26:21,793 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:406: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 13:26:21,794 - stpipe.Detector1Pipeline.jump - WARNING -   err /= gain_2d
# 2023-12-20 13:26:21,795 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 13:26:21,796 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:407: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 13:26:21,796 - stpipe.Detector1Pipeline.jump - WARNING -   readnoise_2d /= gain_2d
# 2023-12-20 13:26:21,796 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 13:26:22,170 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 73.544329
# 2023-12-20 13:26:22,181 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2023-12-20 13:26:28,629 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg001_nrs2_ramp.fits
# 2023-12-20 13:26:29,238 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_ramp.fits>,).
# 2023-12-20 13:26:29,239 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2023-12-20 13:26:29,269 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits
# 2023-12-20 13:26:29,270 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits
# 2023-12-20 13:26:29,321 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2023-12-20 13:26:29,322 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# 2023-12-20 13:26:29,323 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2023-12-20 13:26:29,323 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2023-12-20 13:26:31,668 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 6
# 2023-12-20 13:32:20,030 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2023-12-20 13:32:20,889 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(32, 2048) from jw01366003001_04101_00001-seg001_nrs2_ramp.fits>,).
# 2023-12-20 13:32:20,891 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:32:20,906 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.428
# 2023-12-20 13:32:20,913 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2023-12-20 13:32:21,416 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_ramp.fits>,).
# 2023-12-20 13:32:21,417 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:32:21,483 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.428
# 2023-12-20 13:32:21,494 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2023-12-20 13:32:21,688 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg001_nrs2_rateints.fits
# 2023-12-20 13:32:21,688 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2023-12-20 13:32:21,689 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 13:32:21,731 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg001_nrs2_rate.fits
# 2023-12-20 13:32:21,732 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# 2023-12-20 13:32:22,736 - CRDS - ERROR -  Error determining best reference for 'pars-chargemigrationstep'  =   Unknown reference type 'pars-chargemigrationstep'
# 2023-12-20 13:32:22,738 - stpipe - INFO - PARS-JUMPSTEP parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-jumpstep_0002.asdf
# 2023-12-20 13:32:22,747 - stpipe - INFO - PARS-DETECTOR1PIPELINE parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-detector1pipeline_0003.asdf
# 2023-12-20 13:32:22,760 - stpipe.Detector1Pipeline - INFO - Detector1Pipeline instance created.
# 2023-12-20 13:32:22,761 - stpipe.Detector1Pipeline.group_scale - INFO - GroupScaleStep instance created.
# 2023-12-20 13:32:22,762 - stpipe.Detector1Pipeline.dq_init - INFO - DQInitStep instance created.
# 2023-12-20 13:32:22,763 - stpipe.Detector1Pipeline.saturation - INFO - SaturationStep instance created.
# 2023-12-20 13:32:22,764 - stpipe.Detector1Pipeline.ipc - INFO - IPCStep instance created.
# 2023-12-20 13:32:22,765 - stpipe.Detector1Pipeline.superbias - INFO - SuperBiasStep instance created.
# 2023-12-20 13:32:22,766 - stpipe.Detector1Pipeline.refpix - INFO - RefPixStep instance created.
# 2023-12-20 13:32:22,767 - stpipe.Detector1Pipeline.rscd - INFO - RscdStep instance created.
# 2023-12-20 13:32:22,767 - stpipe.Detector1Pipeline.firstframe - INFO - FirstFrameStep instance created.
# 2023-12-20 13:32:22,768 - stpipe.Detector1Pipeline.lastframe - INFO - LastFrameStep instance created.
# 2023-12-20 13:32:22,769 - stpipe.Detector1Pipeline.linearity - INFO - LinearityStep instance created.
# 2023-12-20 13:32:22,770 - stpipe.Detector1Pipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2023-12-20 13:32:22,770 - stpipe.Detector1Pipeline.reset - INFO - ResetStep instance created.
# 2023-12-20 13:32:22,771 - stpipe.Detector1Pipeline.persistence - INFO - PersistenceStep instance created.
# 2023-12-20 13:32:22,772 - stpipe.Detector1Pipeline.charge_migration - INFO - ChargeMigrationStep instance created.
# 2023-12-20 13:32:22,774 - stpipe.Detector1Pipeline.jump - INFO - JumpStep instance created.
# 2023-12-20 13:32:22,775 - stpipe.Detector1Pipeline.ramp_fit - INFO - RampFitStep instance created.
# 2023-12-20 13:32:22,775 - stpipe.Detector1Pipeline.gain_scale - INFO - GainScaleStep instance created.
# 2023-12-20 13:32:23,280 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline running with args ('/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data/jw01366003001_04101_00001-seg002_nrs2_uncal.fits',).
# 2023-12-20 13:32:23,287 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_calibrated_ramp': True, 'steps': {'group_scale': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dq_init': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'saturation': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'n_pix_grow_sat': 1}, 'ipc': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'superbias': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'refpix': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}, 'rscd': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'type': 'baseline'}, 'firstframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'lastframe': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'linearity': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'dark_current': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'dark_output': None}, 'reset': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'persistence': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_us ...
# 2023-12-20 13:32:24,240 - stpipe.Detector1Pipeline - INFO - Prefetching reference files for dataset: 'jw01366003001_04101_00001-seg002_nrs2_uncal.fits' reftypes = ['dark', 'gain', 'linearity', 'mask', 'readnoise', 'refpix', 'reset', 'saturation', 'superbias']
# 2023-12-20 13:32:24,244 - stpipe.Detector1Pipeline - INFO - Prefetch for DARK reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0218.fits'.
# 2023-12-20 13:32:24,244 - stpipe.Detector1Pipeline - INFO - Prefetch for GAIN reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits'.
# 2023-12-20 13:32:24,244 - stpipe.Detector1Pipeline - INFO - Prefetch for LINEARITY reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0023.fits'.
# 2023-12-20 13:32:24,245 - stpipe.Detector1Pipeline - INFO - Prefetch for MASK reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0049.fits'.
# 2023-12-20 13:32:24,245 - stpipe.Detector1Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits'.
# 2023-12-20 13:32:24,246 - stpipe.Detector1Pipeline - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2023-12-20 13:32:24,246 - stpipe.Detector1Pipeline - INFO - Prefetch for RESET reference file is 'N/A'.
# 2023-12-20 13:32:24,246 - stpipe.Detector1Pipeline - INFO - Prefetch for SATURATION reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0029.fits'.
# 2023-12-20 13:32:24,247 - stpipe.Detector1Pipeline - INFO - Prefetch for SUPERBIAS reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0429.fits'.
# 2023-12-20 13:32:24,248 - stpipe.Detector1Pipeline - INFO - Starting calwebb_detector1 ...
# 2023-12-20 13:32:27,221 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:32:27,222 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:32:28,770 - stpipe.Detector1Pipeline.group_scale - INFO - NFRAMES and FRMDIVSR are equal; correction not needed
# 2023-12-20 13:32:28,771 - stpipe.Detector1Pipeline.group_scale - INFO - Step will be skipped
# 2023-12-20 13:32:28,773 - stpipe.Detector1Pipeline.group_scale - INFO - Step group_scale done
# 2023-12-20 13:32:29,499 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:32:29,500 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:32:29,518 - stpipe.Detector1Pipeline.dq_init - INFO - Using MASK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_mask_0049.fits
# 2023-12-20 13:32:31,247 - stpipe.Detector1Pipeline.dq_init - INFO - Extracting mask subarray to match science data
# 2023-12-20 13:32:32,355 - stpipe.Detector1Pipeline.dq_init - INFO - Step dq_init done
# 2023-12-20 13:32:33,035 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:32:33,036 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'n_pix_grow_sat': 1}
# 2023-12-20 13:32:33,054 - stpipe.Detector1Pipeline.saturation - INFO - Using SATURATION reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_saturation_0029.fits
# 2023-12-20 13:32:34,671 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2023-12-20 13:32:51,521 - stpipe.Detector1Pipeline.saturation - INFO - Detected 1002 saturated pixels
# 2023-12-20 13:32:51,759 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2023-12-20 13:32:51,766 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2023-12-20 13:32:52,455 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:32:52,456 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:32:52,456 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2023-12-20 13:32:52,458 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2023-12-20 13:32:52,916 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:32:52,917 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:32:52,936 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0429.fits
# 2023-12-20 13:32:54,703 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2023-12-20 13:32:55,390 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:32:55,391 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}
# 2023-12-20 13:32:56,958 - stpipe.Detector1Pipeline.refpix - INFO - NIR subarray data
# 2023-12-20 13:32:56,959 - stpipe.Detector1Pipeline.refpix - INFO - Single readout amplifier used
# 2023-12-20 13:32:56,960 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2023-12-20 13:32:56,960 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2023-12-20 13:32:56,960 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2023-12-20 13:32:56,960 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2023-12-20 13:32:56,961 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2023-12-20 13:32:56,961 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.0
# 2023-12-20 13:32:56,961 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = False
# 2023-12-20 13:33:30,885 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2023-12-20 13:33:31,555 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:33:31,556 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:33:31,574 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0023.fits
# 2023-12-20 13:33:31,610 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-12-20 13:33:34,776 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2023-12-20 13:33:35,460 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:33:35,461 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'dark_output': None}
# 2023-12-20 13:33:35,479 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0218.fits
# 2023-12-20 13:33:35,517 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=155, ngroups=70, nframes=1, groupgap=0
# 2023-12-20 13:33:35,517 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=10, nframes=1, groupgap=0
# 2023-12-20 13:33:35,518 - stpipe.Detector1Pipeline.dark_current - WARNING - Not enough data in dark reference file to match to science data.
# 2023-12-20 13:33:35,518 - stpipe.Detector1Pipeline.dark_current - WARNING - Input will be returned without subtracting dark current.
# 2023-12-20 13:33:37,278 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2023-12-20 13:33:37,741 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# 2023-12-20 13:33:37,742 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'signal_threshold': 25000.0}
# 2023-12-20 13:33:37,743 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2023-12-20 13:33:37,745 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration done
# 2023-12-20 13:33:38,212 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_uncal.fits>,).
# ...
# 2023-12-20 13:38:05,169 - stpipe.Detector1Pipeline.saturation - INFO - Extracting reference file subarray to match science data
# 2023-12-20 13:38:21,840 - stpipe.Detector1Pipeline.saturation - INFO - Detected 849 saturated pixels
# 2023-12-20 13:38:22,096 - stpipe.Detector1Pipeline.saturation - INFO - Detected 0 A/D floor pixels
# 2023-12-20 13:38:22,103 - stpipe.Detector1Pipeline.saturation - INFO - Step saturation done
# 2023-12-20 13:38:22,792 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:38:22,793 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:38:22,793 - stpipe.Detector1Pipeline.ipc - INFO - Step skipped.
# 2023-12-20 13:38:22,796 - stpipe.Detector1Pipeline.ipc - INFO - Step ipc done
# 2023-12-20 13:38:23,259 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:38:23,260 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:38:23,281 - stpipe.Detector1Pipeline.superbias - INFO - Using SUPERBIAS reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_superbias_0429.fits
# 2023-12-20 13:38:24,992 - stpipe.Detector1Pipeline.superbias - INFO - Step superbias done
# 2023-12-20 13:38:25,675 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:38:25,676 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'odd_even_columns': True, 'use_side_ref_pixels': True, 'side_smoothing_length': 11, 'side_gain': 1.0, 'odd_even_rows': True, 'ovr_corr_mitigation_ftr': 3.0}
# 2023-12-20 13:38:27,216 - stpipe.Detector1Pipeline.refpix - INFO - NIR subarray data
# 2023-12-20 13:38:27,218 - stpipe.Detector1Pipeline.refpix - INFO - Single readout amplifier used
# 2023-12-20 13:38:27,218 - stpipe.Detector1Pipeline.refpix - INFO - The following parameter is valid for this mode:
# 2023-12-20 13:38:27,218 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_columns = True
# 2023-12-20 13:38:27,219 - stpipe.Detector1Pipeline.refpix - INFO - The following parameters are not applicable and are ignored:
# 2023-12-20 13:38:27,219 - stpipe.Detector1Pipeline.refpix - INFO - use_side_ref_pixels = True
# 2023-12-20 13:38:27,219 - stpipe.Detector1Pipeline.refpix - INFO - side_smoothing_length = 11
# 2023-12-20 13:38:27,219 - stpipe.Detector1Pipeline.refpix - INFO - side_gain = 1.0
# 2023-12-20 13:38:27,220 - stpipe.Detector1Pipeline.refpix - INFO - odd_even_rows = False
# 2023-12-20 13:39:00,388 - stpipe.Detector1Pipeline.refpix - INFO - Step refpix done
# 2023-12-20 13:39:01,085 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:39:01,086 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:39:01,105 - stpipe.Detector1Pipeline.linearity - INFO - Using Linearity reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_linearity_0023.fits
# 2023-12-20 13:39:01,140 - stpipe.Detector1Pipeline.linearity - WARNING - Keyword BAD_LIN_CORR does not correspond to an existing DQ mnemonic, so will be ignored
# 2023-12-20 13:39:04,258 - stpipe.Detector1Pipeline.linearity - INFO - Step linearity done
# 2023-12-20 13:39:04,942 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:39:04,943 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'dark_output': None}
# 2023-12-20 13:39:04,962 - stpipe.Detector1Pipeline.dark_current - INFO - Using DARK reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_dark_0218.fits
# 2023-12-20 13:39:04,998 - stpipe.Detector1Pipeline.dark_current - INFO - Science data nints=155, ngroups=70, nframes=1, groupgap=0
# 2023-12-20 13:39:04,999 - stpipe.Detector1Pipeline.dark_current - INFO - Dark data nints=1, ngroups=10, nframes=1, groupgap=0
# 2023-12-20 13:39:04,999 - stpipe.Detector1Pipeline.dark_current - WARNING - Not enough data in dark reference file to match to science data.
# 2023-12-20 13:39:05,000 - stpipe.Detector1Pipeline.dark_current - WARNING - Input will be returned without subtracting dark current.
# 2023-12-20 13:39:06,693 - stpipe.Detector1Pipeline.dark_current - INFO - Step dark_current done
# 2023-12-20 13:39:07,168 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:39:07,169 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'signal_threshold': 25000.0}
# 2023-12-20 13:39:07,169 - stpipe.Detector1Pipeline.charge_migration - INFO - Step skipped.
# 2023-12-20 13:39:07,171 - stpipe.Detector1Pipeline.charge_migration - INFO - Step charge_migration done
# 2023-12-20 13:39:07,636 - stpipe.Detector1Pipeline.jump - INFO - Step jump running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_uncal.fits>,).
# 2023-12-20 13:39:07,638 - stpipe.Detector1Pipeline.jump - INFO - Step jump parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'rejection_threshold': 4.0, 'three_group_rejection_threshold': 6.0, 'four_group_rejection_threshold': 5.0, 'maximum_cores': 'half', 'flag_4_neighbors': True, 'max_jump_to_flag_neighbors': 1000.0, 'min_jump_to_flag_neighbors': 10.0, 'after_jump_flag_dn1': 1000, 'after_jump_flag_time1': 90, 'after_jump_flag_dn2': 0, 'after_jump_flag_time2': 0, 'expand_large_events': False, 'min_sat_area': 1, 'min_jump_area': 5, 'expand_factor': 2.0, 'use_ellipses': False, 'sat_required_snowball': True, 'min_sat_radius_extend': 2.5, 'sat_expand': 2, 'edge_size': 25, 'find_showers': False, 'extend_snr_threshold': 1.2, 'extend_min_area': 90, 'extend_inner_radius': 1.0, 'extend_outer_radius': 2.6, 'extend_ellipse_expand_ratio': 1.1, 'time_masked_after_shower': 15.0, 'max_extended_radius': 200, 'minimum_groups': 3, 'minimum_sigclip_groups': 100, 'only_use_ints': True}
# 2023-12-20 13:39:07,648 - stpipe.Detector1Pipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2023-12-20 13:39:07,648 - stpipe.Detector1Pipeline.jump - INFO - Maximum cores to use = half
# 2023-12-20 13:39:07,658 - stpipe.Detector1Pipeline.jump - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits
# 2023-12-20 13:39:07,693 - stpipe.Detector1Pipeline.jump - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits
# 2023-12-20 13:39:09,205 - stpipe.Detector1Pipeline.jump - INFO - Extracting gain subarray to match science data
# 2023-12-20 13:39:09,206 - stpipe.Detector1Pipeline.jump - INFO - Extracting readnoise subarray to match science data
# 2023-12-20 13:39:09,453 - stpipe.Detector1Pipeline.jump - INFO - Executing two-point difference method
# 2023-12-20 13:39:10,300 - stpipe.Detector1Pipeline.jump - INFO - Creating 6 processes for jump detection
# 2023-12-20 13:40:21,559 - stpipe.Detector1Pipeline.jump - INFO - Total elapsed time = 72.1049 sec
# 2023-12-20 13:40:22,652 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:405: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 13:40:22,653 - stpipe.Detector1Pipeline.jump - WARNING -   data /= gain_2d
# 2023-12-20 13:40:22,653 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 13:40:23,568 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:406: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 13:40:23,568 - stpipe.Detector1Pipeline.jump - WARNING -   err /= gain_2d
# 2023-12-20 13:40:23,568 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 13:40:23,569 - stpipe.Detector1Pipeline.jump - WARNING - /Users/nnikolov/anaconda3/envs/jwst.1.12.5/lib/python3.11/site-packages/stcal/jump/jump.py:407: RuntimeWarning: invalid value encountered in divide
# 2023-12-20 13:40:23,569 - stpipe.Detector1Pipeline.jump - WARNING -   readnoise_2d /= gain_2d
# 2023-12-20 13:40:23,570 - stpipe.Detector1Pipeline.jump - WARNING -
# 2023-12-20 13:40:23,940 - stpipe.Detector1Pipeline.jump - INFO - The execution time in seconds: 76.292890
# 2023-12-20 13:40:23,949 - stpipe.Detector1Pipeline.jump - INFO - Step jump done
# 2023-12-20 13:40:30,557 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs2_ramp.fits
# 2023-12-20 13:40:31,128 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit running with args (<RampModel(155, 70, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_ramp.fits>,).
# 2023-12-20 13:40:31,129 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data', 'int_name': '', 'save_opt': False, 'opt_name': '', 'suppress_one_group': True, 'maximum_cores': 'half'}
# 2023-12-20 13:40:31,156 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits
# 2023-12-20 13:40:31,156 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using GAIN reference file: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits
# 2023-12-20 13:40:31,203 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting gain subarray to match science data
# 2023-12-20 13:40:31,204 - stpipe.Detector1Pipeline.ramp_fit - INFO - Extracting readnoise subarray to match science data
# 2023-12-20 13:40:31,205 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using algorithm = ols
# 2023-12-20 13:40:31,205 - stpipe.Detector1Pipeline.ramp_fit - INFO - Using weighting = optimal
# 2023-12-20 13:40:33,466 - stpipe.Detector1Pipeline.ramp_fit - INFO - Number of processors used for multiprocessing: 6
# 2023-12-20 13:44:47,223 - stpipe.Detector1Pipeline.ramp_fit - INFO - Step ramp_fit done
# 2023-12-20 13:44:47,938 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<ImageModel(32, 2048) from jw01366003001_04101_00001-seg003_nrs2_ramp.fits>,).
# 2023-12-20 13:44:47,941 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scale', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:44:47,954 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.428
# 2023-12-20 13:44:47,960 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2023-12-20 13:44:48,415 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_ramp.fits>,).
# 2023-12-20 13:44:48,416 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'gain_scaleints', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/data'}
# 2023-12-20 13:44:48,478 - stpipe.Detector1Pipeline.gain_scale - INFO - Rescaling by 1.428
# 2023-12-20 13:44:48,488 - stpipe.Detector1Pipeline.gain_scale - INFO - Step gain_scale done
# 2023-12-20 13:44:48,725 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs2_rateints.fits
# 2023-12-20 13:44:48,725 - stpipe.Detector1Pipeline - INFO - ... ending calwebb_detector1
# 2023-12-20 13:44:48,726 - stpipe.Detector1Pipeline - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 13:44:48,767 - stpipe.Detector1Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs2_rate.fits
# 2023-12-20 13:44:48,767 - stpipe.Detector1Pipeline - INFO - Step Detector1Pipeline done
# Run time:  21.041666666666668  min

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 3](#stage3)

# %% [markdown]
# ---
#
# ### <font color='white'>-</font>Stage 2: Spec2Pipeline <a class="anchor" id="stage2"></a>
#
# ---

# %% [markdown]
# The `Spec2Pipeline` performs additional instrumental corrections and calibrations to produce fully calibrated exposure. Details of the specific steps that need to be included for the BOTS mode are documented in the <a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_spec2.html">calwebb_spec2: Stage 2 Spectroscopic Processing.</a>
#
# Prior to running the pipeline, we will perform two modifications.
# 1. Remove 1/f noise
# 2. Modify the aperture size with which we will run the `extract_1d` step
#
# JWST detector readout electronics (aka SIDECAR ASICs) generate significant 1/f noise during detector operations and signal digitization. When using NIRSpec BOTS, this 1/f noise appears as vertical banding that spans the entire width of the 2d spectral image, and varies from column to column. If not handled properly, the 1/f noise can introduce systematic errors and extra scatter in the light curves. For more information, please visit: <a href="https://jwst-docs.stsci.edu/methods-and-roadmaps/jwst-time-series-observations/jwst-time-series-observations-noise-sources#JWSTTimeSeriesObservationsNoiseSources-1/fnoise">JWST Time-Series Observations Noise Sources.</a>
#
# At the time of writing, NSClean has been envisioned as the default 1/f-noise removal algorithm for the STScI pipeline. Given this function is still under implementation, we will remove 1/f noise by subtracting the median background flux on a column-by-column basis. The function below will perform this task.

# %%
def correct_one_over_f(image, b_low, b_high, detector_id):
    # Inputs:
    # image - image to correct, 2D array
    # blow - lower column pixels for the two regions, a tuple of two values 
    # bhigh - higher column pixels for the two regions, a tuple of two values

    y_lo_1, y_lo_2 = b_low
    y_hi_1, y_hi_2 = b_high
    
    corrected_image = np.copy(image)
    for i in range(image.shape[1]):
        #print(image.shape[1])
        
        if (detector_id == 'nrs1'):
            corrected_image[:, i] = image[:, i] - np.nanmedian( np.concatenate((image[y_lo_1:y_hi_1,i],image[y_lo_2:y_hi_2,i])) )

        if (detector_id == 'nrs2'):
            if (i <= 1250):
                corrected_image[:, i] = image[:, i] - np.nanmedian( image[y_lo_1:y_hi_1,i] )
            if (i > 1250):
                corrected_image[:, i] = image[:, i] - np.nanmedian( image[y_lo_2:y_hi_2,i] )

    return corrected_image

# %% [markdown]
# We next specify the background region that the 1/f noise function will use for subtraction.

# %%
from astropy.io import fits

n_segments = len(froot)

if process_detector == 'nrs1':
    b_low  = (0, 26)
    b_high = (5, 31)

if process_detector == 'nrs2':
    b_low  = (26, 0)
    b_high = (31, 5)


for i in range(n_segments):
    print('\nRemoving 1overf noise from segment ', i+1, ' out of ', n_segments)
    ramp_HDUL = datamodels.open(stage1_dir + froot[i] + 'rateints.fits')
    #ramp_HDUL.info() # Use this command if you wish to take a look at the data model contents
    ramp_sci = ramp_HDUL.data
    
    #ramp_HDUL = fits.open(stage1_dir + froot[i] + 'rateints.fits')
    #ramp_sci = ramp_HDUL[1].data
    
    corrected_1overf_2Dspec = np.copy(ramp_sci)
    for j in range(len(ramp_sci[:,0,0])):
        corrected_1overf_2Dspec[j, :, :] = correct_one_over_f( ramp_sci[j, :, :], b_low, b_high, process_detector )
    ramp_HDUL.data = corrected_1overf_2Dspec
    ramp_HDUL.save(stage1_dir + froot[i] + 'rateints_1cl.fits') # add '1cl' suffix to indicate 1/f-cleaned 2D spectra
    #ramp_HDUL[1].data = corrected_1overf_2Dspec
    #ramp_HDUL.writeto(stage1_dir + froot[i] + 'rateints_1cl.fits', overwrite=True) # add '1cl' suffix to indicate 1/f-cleaned 2D spectra
    ramp_HDUL.close()
# Out:
# Removing 1overf noise from segment  1  out of  3
#
# Removing 1overf noise from segment  2  out of  3
#
# Removing 1overf noise from segment  3  out of  3

# %% [markdown]
# Next, we can plot the uncorrected vs 1/f-corrected image, as well as the difference to inspect for any residuals.

# %%
if process_detector == 'nrs1':
    int_id  = 100 # select an integration to show
    f_lo = -0.5 # lower limit for flux
    f_hi = +0.5 # upper limit for flux

if process_detector == 'nrs2':
    int_id  = 0 # select an integration to show
    f_lo = -0.5 # lower limit for flux
    f_hi = +0.5 # upper limit for flux

# Plot the original uncorrected image
plt.figure(figsize=(20,8))
plt.subplot(211)
plt.title('Uncorrected 2D spectrum ' + process_detector.upper(), fontsize=20)
im1 = plt.imshow(ramp_sci[int_id,:,:], 
                 interpolation='None', 
                 aspect='auto', 
                 cmap='inferno', 
                 origin='lower',
                 clim=(f_lo, f_hi))

plt.xlabel('x-column', fontsize=15)
plt.ylabel('y-row', fontsize=15)

cb1 = plt.colorbar(label=r'Counts, DN/s')




# Plot the corrected image
plt.figure(figsize=(20,8))
plt.subplot(211)
plt.title('1/f-corrected 2D spectrum ' + process_detector.upper(), fontsize=20)
im1 = plt.imshow(corrected_1overf_2Dspec[int_id,:,:], 
                 interpolation='None', 
                 aspect='auto', 
                 cmap='inferno', 
                 origin='lower',
                 clim=(f_lo, f_hi))

plt.xlabel('x-column', fontsize=15)
plt.ylabel('y-row', fontsize=15)

cb1 = plt.colorbar(label=r'Counts, DN/s')



# Plot the difference image
plt.figure(figsize=(20,8))
plt.subplot(211)
plt.title('Difference 2D spectrum ' + process_detector.upper(), fontsize=20)
im1 = plt.imshow(ramp_sci[int_id,:,:] - corrected_1overf_2Dspec[int_id,:,:], 
                 interpolation='None', 
                 aspect='auto', 
                 cmap='inferno', 
                 origin='lower',
                 clim=(f_lo, f_hi))

plt.xlabel('x-column', fontsize=15)
plt.ylabel('y-row', fontsize=15)

cb1 = plt.colorbar(label=r'Counts, DN/s')

plt.show()

# %% [markdown]
# The correction looks good with no significant residual as shown by the difference image.
#
# Finally, we modify the parameter reference file of th `extract_1d` step to specify the width od the extraction aperture and enable other useful parameters detailed in the next cell. This and several additional parameter reference files are located in the `CRDS_PATH` directory. One can modify them "by hand" some of them, such as .json files. We opt to modify using the cell below.

# %%
import json

json_name = 'jwst_nirspec_extract1d_0006.json'
json_dir = os.environ['CRDS_PATH'] + '/references/jwst/nirspec/'

# open file in read-mode
with open(json_dir + json_name, 'r') as file:
    # read JSON data
    data = json.load(file)
    if (process_detector == 'nrs1'):
        data['apertures'][0]['extract_width'] = 6 # extraction aperture radius in pixels
        data['apertures'][0]['xstart'] = 100 # lower x-index 
    if process_detector == 'nrs2':
        data['apertures'][0]['extract_width'] = 27 # extraction aperture radius in pixels        
#    data['apertures'][0]['xstop'] = 300 # upper x-index
#    data['apertures'][0]['ystart'] = 5
#    data['apertures'][0]['ystop'] = 25
#    data['apertures'][0]['nod2_offset'] = 0 # apply no offsets
    data['apertures'][0].pop("nod2_offset") # remove
#    data['apertures'][0]['nod3_offset'] = 0
    data['apertures'][0].pop("nod3_offset") # remove
    #data['apertures'][0]['nod5_offset'] = 0
    data['apertures'][0].pop("nod5_offset") # remove
#    print(data['apertures'][0]['extract_width'])

newData = json.dumps(data, indent=4)
#print(json_name[:-5])
with open(json_dir + json_name[:-5] + '_bots.json', 'w') as file: # add the suffix '_bots' to distinguish the file from the default version.
    # write
    file.write(newData)

# %%
from jwst.pipeline import Spec2Pipeline

# %% [markdown]
# The runtime of the `Spec2` step takes approximately 6 minutes for all segments.

# %%
param_stage2 = {
    'assign_wcs'    :{'skip': False},
    'extract_2d'    :{'skip': False},
    'srctype'       :{'skip': False},
    'flat_field'    :{'skip': True}, # we opt to skip this step, because it can introduce spurious pixels that can affect the light curve scatter
    'photom'        :{'skip': True}, # we also skip this step, because BOTS exoplanet observations are relative 
    'pixel_replace' :{'skip': False, 'n_adjacent_cols': 5, 'algorithm':"fit_profile"}, #, 'algorithm':'mingrad'
    'extract_1d'    :{'skip': False, 'override_extract1d': f'{json_dir + json_name[:-5]}_bots.json', 'apply_apcorr': False, 'subtract_background': False } # 'dispaxis': 1, 'xstart': 100, 'xstop': 150, 'extract_width': 10},
}

start = tt.time()

for i in range(len(files)):
    Spec2Pipeline.call(stage1_dir + froot[i]+'rateints_1cl.fits', 
                       save_results = True, 
                       steps        = param_stage2, 
                       output_dir   = stage2_dir)

end = tt.time()
print("Run time: ", round(end-start,1)/60.0, " min")
# Out:
# 2023-12-20 15:05:44,976 - CRDS - ERROR -  Error determining best reference for 'pars-pixelreplacestep'  =   Unknown reference type 'pars-pixelreplacestep'
# 2023-12-20 15:05:44,979 - stpipe - INFO - PARS-SPEC2PIPELINE parameters found: /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_pars-spec2pipeline_0022.asdf
# 2023-12-20 15:05:44,997 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2023-12-20 15:05:44,998 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2023-12-20 15:05:44,999 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2023-12-20 15:05:45,000 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2023-12-20 15:05:45,001 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2023-12-20 15:05:45,002 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2023-12-20 15:05:45,004 - stpipe.Spec2Pipeline.master_background_mos - INFO - MasterBackgroundMosStep instance created.
# 2023-12-20 15:05:45,005 - stpipe.Spec2Pipeline.master_background_mos.flat_field - INFO - FlatFieldStep instance created.
# 2023-12-20 15:05:45,006 - stpipe.Spec2Pipeline.master_background_mos.pathloss - INFO - PathLossStep instance created.
# 2023-12-20 15:05:45,006 - stpipe.Spec2Pipeline.master_background_mos.barshadow - INFO - BarShadowStep instance created.
# 2023-12-20 15:05:45,007 - stpipe.Spec2Pipeline.master_background_mos.photom - INFO - PhotomStep instance created.
# 2023-12-20 15:05:45,008 - stpipe.Spec2Pipeline.wavecorr - INFO - WavecorrStep instance created.
# 2023-12-20 15:05:45,009 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2023-12-20 15:05:45,010 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2023-12-20 15:05:45,010 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2023-12-20 15:05:45,011 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2023-12-20 15:05:45,012 - stpipe.Spec2Pipeline.residual_fringe - INFO - ResidualFringeStep instance created.
# 2023-12-20 15:05:45,012 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2023-12-20 15:05:45,013 - stpipe.Spec2Pipeline.barshadow - INFO - BarShadowStep instance created.
# 2023-12-20 15:05:45,014 - stpipe.Spec2Pipeline.wfss_contam - INFO - WfssContamStep instance created.
# 2023-12-20 15:05:45,015 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2023-12-20 15:05:45,016 - stpipe.Spec2Pipeline.pixel_replace - INFO - PixelReplaceStep instance created.
# 2023-12-20 15:05:45,017 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2023-12-20 15:05:45,018 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2023-12-20 15:05:45,019 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2023-12-20 15:05:45,718 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits',).
# 2023-12-20 15:05:45,728 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_bsub': False, 'fail_on_exception': True, 'save_wfss_esec': False, 'steps': {'bkg_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}, 'assign_wcs': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}, 'imprint_subtract': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'msa_flagging': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': ''}, 'extract_2d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': None, 'wfss_nbright': 1000}, 'master_background_mos': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'user_slit_loc': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}}},  ...
# 2023-12-20 15:05:45,794 - stpipe.Spec2Pipeline - INFO - Prefetching reference files for dataset: 'jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits' reftypes = ['apcorr', 'camera', 'collimator', 'disperser', 'distortion', 'filteroffset', 'fore', 'fpa', 'fringe', 'ifufore', 'ifupost', 'ifuslicer', 'msa', 'ote', 'regions', 'speckernel', 'specprofile', 'spectrace', 'specwcs', 'wavecorr', 'wavelengthrange', 'wavemap']
# 2023-12-20 15:05:45,797 - stpipe.Spec2Pipeline - INFO - Prefetch for APCORR reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_apcorr_0003.fits'.
# 2023-12-20 15:05:45,798 - stpipe.Spec2Pipeline - INFO - Prefetch for CAMERA reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf'.
# 2023-12-20 15:05:45,799 - stpipe.Spec2Pipeline - INFO - Prefetch for COLLIMATOR reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf'.
# 2023-12-20 15:05:45,799 - stpipe.Spec2Pipeline - INFO - Prefetch for DISPERSER reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf'.
# 2023-12-20 15:05:45,800 - stpipe.Spec2Pipeline - INFO - Prefetch for DISTORTION reference file is 'N/A'.
# 2023-12-20 15:05:45,800 - stpipe.Spec2Pipeline - INFO - Override for EXTRACT1D reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0006_bots.json'.
# 2023-12-20 15:05:45,801 - stpipe.Spec2Pipeline - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2023-12-20 15:05:45,801 - stpipe.Spec2Pipeline - INFO - Prefetch for FORE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf'.
# 2023-12-20 15:05:45,802 - stpipe.Spec2Pipeline - INFO - Prefetch for FPA reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf'.
# 2023-12-20 15:05:45,803 - stpipe.Spec2Pipeline - INFO - Prefetch for FRINGE reference file is 'N/A'.
# 2023-12-20 15:05:45,803 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2023-12-20 15:05:45,803 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2023-12-20 15:05:45,804 - stpipe.Spec2Pipeline - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2023-12-20 15:05:45,804 - stpipe.Spec2Pipeline - INFO - Prefetch for MSA reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf'.
# 2023-12-20 15:05:45,805 - stpipe.Spec2Pipeline - INFO - Prefetch for OTE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0010.asdf'.
# 2023-12-20 15:05:45,805 - stpipe.Spec2Pipeline - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2023-12-20 15:05:45,805 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECKERNEL reference file is 'N/A'.
# 2023-12-20 15:05:45,806 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECPROFILE reference file is 'N/A'.
# 2023-12-20 15:05:45,806 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECTRACE reference file is 'N/A'.
# 2023-12-20 15:05:45,806 - stpipe.Spec2Pipeline - INFO - Prefetch for SPECWCS reference file is 'N/A'.
# 2023-12-20 15:05:45,807 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVECORR reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavecorr_0003.asdf'.
# 2023-12-20 15:05:45,807 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf'.
# 2023-12-20 15:05:45,808 - stpipe.Spec2Pipeline - INFO - Prefetch for WAVEMAP reference file is 'N/A'.
# 2023-12-20 15:05:45,808 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2023-12-20 15:05:45,809 - stpipe.Spec2Pipeline - INFO - Processing product /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg001_nrs2_rateints_1cl
# 2023-12-20 15:05:45,809 - stpipe.Spec2Pipeline - INFO - Working on input /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits ...
# 2023-12-20 15:05:46,523 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:46,524 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'sip_approx': True, 'sip_max_pix_error': 0.1, 'sip_degree': None, 'sip_max_inv_pix_error': 0.1, 'sip_inv_degree': None, 'sip_npoints': 12, 'slit_y_low': -0.55, 'slit_y_high': 0.55}
# 2023-12-20 15:05:46,679 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.1446726469999745 deg
# 2023-12-20 15:05:46,679 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3188409810000999 deg
# 2023-12-20 15:05:46,680 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.0005219736831524339 deg
# 2023-12-20 15:05:46,681 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 6.057163671155447e-05 deg
# 2023-12-20 15:05:46,829 - stpipe.Spec2Pipeline.assign_wcs - INFO - Slits projected on detector NRS2: ['S1600A1']
# 2023-12-20 15:05:46,830 - stpipe.Spec2Pipeline.assign_wcs - INFO - Computing WCS for 1 open slitlets
# 2023-12-20 15:05:46,856 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_ytilt is 0.1446726469999745 deg
# 2023-12-20 15:05:46,857 - stpipe.Spec2Pipeline.assign_wcs - INFO - gwa_xtilt is 0.3188409810000999 deg
# 2023-12-20 15:05:46,857 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_y correction: 0.0005219736831524339 deg
# 2023-12-20 15:05:46,858 - stpipe.Spec2Pipeline.assign_wcs - INFO - theta_x correction: 6.057163671155447e-05 deg
# 2023-12-20 15:05:46,873 - stpipe.Spec2Pipeline.assign_wcs - INFO - SPORDER= -1, wrange=[2.87e-06, 5.27e-06]
# 2023-12-20 15:05:46,962 - stpipe.Spec2Pipeline.assign_wcs - INFO - Applied Barycentric velocity correction : 0.9999036496553831
# 2023-12-20 15:05:46,992 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 1
# 2023-12-20 15:05:46,993 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 2
# 2023-12-20 15:05:46,993 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 3
# 2023-12-20 15:05:46,994 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 0 open slits in quadrant 4
# 2023-12-20 15:05:46,994 - stpipe.Spec2Pipeline.assign_wcs - INFO - There are 1 open slits in quadrant 5
# 2023-12-20 15:05:47,124 - stpipe.Spec2Pipeline.assign_wcs - INFO - Created a NIRSPEC nrs_brightobj pipeline with references {'distortion': None, 'filteroffset': None, 'specwcs': None, 'regions': None, 'wavelengthrange': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavelengthrange_0006.asdf', 'camera': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_camera_0007.asdf', 'collimator': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_collimator_0007.asdf', 'disperser': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_disperser_0056.asdf', 'fore': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fore_0047.asdf', 'fpa': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_fpa_0008.asdf', 'msa': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_msa_0008.asdf', 'ote': '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_ote_0010.asdf', 'ifupost': None, 'ifufore': None, 'ifuslicer': None}
# 2023-12-20 15:05:47,214 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2023-12-20 15:05:47,227 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2023-12-20 15:05:47,888 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>, []).
# 2023-12-20 15:05:47,889 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1'}
# 2023-12-20 15:05:47,889 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step skipped.
# 2023-12-20 15:05:47,891 - stpipe.Spec2Pipeline.imprint_subtract - INFO - Step imprint_subtract done
# 2023-12-20 15:05:48,550 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>, []).
# 2023-12-20 15:05:48,551 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'save_combined_background': False, 'sigma': 3.0, 'maxiters': None, 'wfss_mmag_extract': None}
# 2023-12-20 15:05:48,551 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step skipped.
# 2023-12-20 15:05:48,554 - stpipe.Spec2Pipeline.bkg_subtract - INFO - Step bkg_subtract done
# 2023-12-20 15:05:49,215 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:49,216 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1'}
# 2023-12-20 15:05:49,216 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step skipped.
# 2023-12-20 15:05:49,218 - stpipe.Spec2Pipeline.msa_flagging - INFO - Step msa_flagging done
# 2023-12-20 15:05:49,876 - stpipe.Spec2Pipeline.extract_2d - INFO - Step extract_2d running with args (<CubeModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:49,877 - stpipe.Spec2Pipeline.extract_2d - INFO - Step extract_2d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'slit_name': None, 'extract_orders': None, 'grism_objects': None, 'tsgrism_extract_height': None, 'wfss_extract_half_height': 5, 'wfss_mmag_extract': None, 'wfss_nbright': 1000}
# 2023-12-20 15:05:49,893 - stpipe.Spec2Pipeline.extract_2d - INFO - EXP_TYPE is NRS_BRIGHTOBJ
# 2023-12-20 15:05:49,990 - stpipe.Spec2Pipeline.extract_2d - INFO - Name of subarray extracted: S1600A1
# 2023-12-20 15:05:49,991 - stpipe.Spec2Pipeline.extract_2d - INFO - Subarray x-extents are: 0 2048
# 2023-12-20 15:05:49,991 - stpipe.Spec2Pipeline.extract_2d - INFO - Subarray y-extents are: 0 35
# 2023-12-20 15:05:50,138 - stpipe.Spec2Pipeline.extract_2d - INFO - set slit_attributes completed
# 2023-12-20 15:05:50,145 - stpipe.Spec2Pipeline.extract_2d - INFO - Update S_REGION to POLYGON ICRS  217.326463389 -3.444792699 217.326917709 -3.444605004 217.326744101 -3.444195992 217.326289754 -3.444383643
# 2023-12-20 15:05:50,147 - stpipe.Spec2Pipeline.extract_2d - INFO - extract_2d updated S_REGION to POLYGON ICRS  217.326463389 -3.444792699 217.326917709 -3.444605004 217.326744101 -3.444195992 217.326289754 -3.444383643
# 2023-12-20 15:05:50,151 - stpipe.Spec2Pipeline.extract_2d - INFO - Step extract_2d done
# 2023-12-20 15:05:50,830 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:50,831 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'source_type': None}
# 2023-12-20 15:05:50,931 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is NRS_BRIGHTOBJ
# 2023-12-20 15:05:50,931 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYAPT = UNKNOWN
# 2023-12-20 15:05:50,932 - stpipe.Spec2Pipeline.srctype - INFO - Input is a TSO exposure; setting SRCTYPE = POINT
# 2023-12-20 15:05:50,936 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2023-12-20 15:05:51,603 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step master_background_mos running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:51,605 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step master_background_mos parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': True, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'force_subtract': False, 'save_background': False, 'user_background': None, 'inverse': False, 'steps': {'flat_field': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}, 'pathloss': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None, 'user_slit_loc': None}, 'barshadow': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}}}
# 2023-12-20 15:05:51,606 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step skipped.
# 2023-12-20 15:05:51,607 - stpipe.Spec2Pipeline.master_background_mos - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 15:05:51,607 - stpipe.Spec2Pipeline.master_background_mos - INFO - Step master_background_mos done
# 2023-12-20 15:05:52,261 - stpipe.Spec2Pipeline.wavecorr - INFO - Step wavecorr running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:52,262 - stpipe.Spec2Pipeline.wavecorr - INFO - Step wavecorr parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1'}
# 2023-12-20 15:05:52,451 - stpipe.Spec2Pipeline.wavecorr - INFO - Using WAVECORR reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_wavecorr_0003.asdf
# 2023-12-20 15:05:52,538 - stpipe.Spec2Pipeline.wavecorr - INFO - Detected a POINT source type in slit S1600A1
# 2023-12-20 15:05:52,538 - stpipe.Spec2Pipeline.wavecorr - INFO - slit name S1600A1
# 2023-12-20 15:05:52,539 - stpipe.Spec2Pipeline.wavecorr - INFO - xoffset, yoffset, 6.03933060849859e-13, -6.0457443092806e-13
# 2023-12-20 15:05:52,550 - stpipe.Spec2Pipeline.wavecorr - INFO - Source X/Y position in the slit: -0.011585206334868, -0.03203498317654394
# 2023-12-20 15:05:52,643 - stpipe.Spec2Pipeline.wavecorr - INFO - Using wavelength zero-point correction for aperture S1600A1
# 2023-12-20 15:05:52,652 - stpipe.Spec2Pipeline.wavecorr - INFO - Step wavecorr done
# 2023-12-20 15:05:53,345 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:53,346 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'save_interpolated_flat': False, 'user_supplied_flat': None, 'inverse': False}
# 2023-12-20 15:05:53,346 - stpipe.Spec2Pipeline.flat_field - INFO - Step skipped.
# 2023-12-20 15:05:53,348 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2023-12-20 15:05:54,016 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:54,017 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None, 'user_slit_loc': None}
# 2023-12-20 15:05:54,017 - stpipe.Spec2Pipeline.pathloss - INFO - Step skipped.
# 2023-12-20 15:05:54,019 - stpipe.Spec2Pipeline.pathloss - INFO - Step pathloss done
# 2023-12-20 15:05:54,690 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:54,690 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None}
# 2023-12-20 15:05:54,691 - stpipe.Spec2Pipeline.barshadow - INFO - Step skipped.
# 2023-12-20 15:05:54,693 - stpipe.Spec2Pipeline.barshadow - INFO - Step barshadow done
# 2023-12-20 15:05:55,360 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:55,361 - stpipe.Spec2Pipeline.photom - INFO - Step photom parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}
# 2023-12-20 15:05:55,361 - stpipe.Spec2Pipeline.photom - INFO - Step skipped.
# 2023-12-20 15:05:55,363 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2023-12-20 15:05:56,030 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl.fits>,).
# 2023-12-20 15:05:56,031 - stpipe.Spec2Pipeline.pixel_replace - INFO - Step pixel_replace parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1', 'algorithm': 'fit_profile', 'n_adjacent_cols': 5}
# 2023-12-20 15:05:56,457 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 0 had 292 pixels replaced.
# 2023-12-20 15:05:56,630 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 1 had 294 pixels replaced.
# 2023-12-20 15:05:56,801 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 2 had 294 pixels replaced.
# 2023-12-20 15:05:56,969 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 3 had 292 pixels replaced.
# 2023-12-20 15:05:57,152 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 4 had 292 pixels replaced.
# 2023-12-20 15:05:57,324 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 5 had 295 pixels replaced.
# 2023-12-20 15:05:57,491 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 6 had 292 pixels replaced.
# 2023-12-20 15:05:57,673 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 7 had 295 pixels replaced.
# 2023-12-20 15:05:57,840 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 8 had 292 pixels replaced.
# 2023-12-20 15:05:58,019 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 9 had 293 pixels replaced.
# 2023-12-20 15:05:58,198 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 10 had 292 pixels replaced.
# 2023-12-20 15:05:58,368 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 11 had 292 pixels replaced.
# 2023-12-20 15:05:58,539 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 12 had 292 pixels replaced.
# 2023-12-20 15:05:58,708 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 13 had 292 pixels replaced.
# 2023-12-20 15:05:58,881 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 14 had 301 pixels replaced.
# 2023-12-20 15:05:59,058 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 15 had 307 pixels replaced.
# 2023-12-20 15:05:59,228 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 16 had 292 pixels replaced.
# 2023-12-20 15:05:59,398 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 17 had 292 pixels replaced.
# 2023-12-20 15:05:59,566 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 18 had 292 pixels replaced.
# 2023-12-20 15:05:59,739 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 19 had 292 pixels replaced.
# 2023-12-20 15:05:59,910 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 20 had 292 pixels replaced.
# 2023-12-20 15:06:00,086 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 21 had 299 pixels replaced.
# 2023-12-20 15:06:00,254 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 22 had 292 pixels replaced.
# 2023-12-20 15:06:00,425 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 23 had 292 pixels replaced.
# 2023-12-20 15:06:00,595 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 24 had 292 pixels replaced.
# 2023-12-20 15:06:00,770 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 25 had 292 pixels replaced.
# 2023-12-20 15:06:00,959 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 26 had 300 pixels replaced.
# 2023-12-20 15:06:01,136 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 27 had 292 pixels replaced.
# 2023-12-20 15:06:01,307 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 28 had 292 pixels replaced.
# 2023-12-20 15:06:01,477 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 29 had 292 pixels replaced.
# 2023-12-20 15:06:01,647 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 30 had 292 pixels replaced.
# 2023-12-20 15:06:01,819 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 31 had 292 pixels replaced.
# 2023-12-20 15:06:01,991 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 32 had 294 pixels replaced.
# 2023-12-20 15:06:02,167 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 33 had 295 pixels replaced.
# 2023-12-20 15:06:02,338 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 34 had 292 pixels replaced.
# 2023-12-20 15:06:02,512 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 35 had 296 pixels replaced.
# 2023-12-20 15:06:02,681 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 36 had 293 pixels replaced.
# 2023-12-20 15:06:02,849 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 37 had 292 pixels replaced.
# 2023-12-20 15:06:03,024 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 38 had 292 pixels replaced.
# 2023-12-20 15:06:03,197 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 39 had 292 pixels replaced.
# 2023-12-20 15:06:03,373 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 40 had 293 pixels replaced.
# 2023-12-20 15:06:03,543 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 41 had 292 pixels replaced.
# 2023-12-20 15:06:03,715 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 42 had 294 pixels replaced.
# 2023-12-20 15:06:03,888 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 43 had 296 pixels replaced.
# 2023-12-20 15:06:04,058 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 44 had 292 pixels replaced.
# 2023-12-20 15:06:04,228 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 45 had 292 pixels replaced.
# 2023-12-20 15:06:04,401 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 46 had 294 pixels replaced.
# 2023-12-20 15:06:04,568 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 47 had 292 pixels replaced.
# 2023-12-20 15:06:04,746 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 48 had 306 pixels replaced.
# 2023-12-20 15:06:04,914 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 49 had 292 pixels replaced.
# 2023-12-20 15:06:05,090 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 50 had 293 pixels replaced.
# 2023-12-20 15:06:05,259 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 51 had 292 pixels replaced.
# 2023-12-20 15:06:05,441 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 52 had 292 pixels replaced.
# 2023-12-20 15:06:05,610 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 53 had 293 pixels replaced.
# 2023-12-20 15:06:05,780 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 54 had 292 pixels replaced.
# 2023-12-20 15:06:05,951 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 55 had 293 pixels replaced.
# 2023-12-20 15:06:06,121 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 56 had 292 pixels replaced.
# 2023-12-20 15:06:06,292 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 57 had 307 pixels replaced.
# 2023-12-20 15:06:06,461 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 58 had 292 pixels replaced.
# 2023-12-20 15:06:06,629 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 59 had 292 pixels replaced.
# 2023-12-20 15:06:06,804 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 60 had 295 pixels replaced.
# 2023-12-20 15:06:06,976 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 61 had 292 pixels replaced.
# 2023-12-20 15:06:07,157 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 62 had 292 pixels replaced.
# 2023-12-20 15:06:07,323 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 63 had 292 pixels replaced.
# 2023-12-20 15:06:07,492 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 64 had 292 pixels replaced.
# 2023-12-20 15:06:07,673 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 65 had 295 pixels replaced.
# 2023-12-20 15:06:07,840 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 66 had 294 pixels replaced.
# 2023-12-20 15:06:08,011 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 67 had 297 pixels replaced.
# 2023-12-20 15:06:08,188 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 68 had 293 pixels replaced.
# 2023-12-20 15:06:08,370 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 69 had 301 pixels replaced.
# 2023-12-20 15:06:08,541 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 70 had 292 pixels replaced.
# 2023-12-20 15:06:08,724 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 71 had 292 pixels replaced.
# 2023-12-20 15:06:08,902 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 72 had 292 pixels replaced.
# 2023-12-20 15:06:09,085 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 73 had 292 pixels replaced.
# 2023-12-20 15:06:09,257 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 74 had 296 pixels replaced.
# 2023-12-20 15:06:09,424 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 75 had 292 pixels replaced.
# 2023-12-20 15:06:09,600 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 76 had 298 pixels replaced.
# 2023-12-20 15:06:09,783 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 77 had 296 pixels replaced.
# 2023-12-20 15:06:09,951 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 78 had 292 pixels replaced.
# 2023-12-20 15:06:10,132 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 79 had 292 pixels replaced.
# 2023-12-20 15:06:10,304 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 80 had 297 pixels replaced.
# 2023-12-20 15:06:10,474 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 81 had 292 pixels replaced.
# 2023-12-20 15:06:10,654 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 82 had 295 pixels replaced.
# 2023-12-20 15:06:10,823 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 83 had 292 pixels replaced.
# 2023-12-20 15:06:11,003 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 84 had 294 pixels replaced.
# 2023-12-20 15:06:11,184 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 85 had 292 pixels replaced.
# 2023-12-20 15:06:11,360 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 86 had 294 pixels replaced.
# 2023-12-20 15:06:11,529 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 87 had 292 pixels replaced.
# 2023-12-20 15:06:11,698 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 88 had 292 pixels replaced.
# 2023-12-20 15:06:11,877 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 89 had 299 pixels replaced.
# 2023-12-20 15:06:12,047 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 90 had 292 pixels replaced.
# 2023-12-20 15:06:12,218 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 91 had 294 pixels replaced.
# 2023-12-20 15:06:12,388 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 92 had 296 pixels replaced.
# 2023-12-20 15:06:12,557 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 93 had 293 pixels replaced.
# 2023-12-20 15:06:12,735 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 94 had 292 pixels replaced.
# 2023-12-20 15:06:12,903 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 95 had 292 pixels replaced.
# 2023-12-20 15:06:13,074 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 96 had 297 pixels replaced.
# 2023-12-20 15:06:13,246 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 97 had 293 pixels replaced.
# 2023-12-20 15:06:13,416 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 98 had 294 pixels replaced.
# 2023-12-20 15:06:13,593 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 99 had 299 pixels replaced.
# 2023-12-20 15:06:13,765 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 100 had 292 pixels replaced.
# 2023-12-20 15:06:13,938 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 101 had 297 pixels replaced.
# 2023-12-20 15:06:14,113 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 102 had 298 pixels replaced.
# 2023-12-20 15:06:14,282 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 103 had 294 pixels replaced.
# 2023-12-20 15:06:14,452 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 104 had 294 pixels replaced.
# 2023-12-20 15:06:14,622 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 105 had 294 pixels replaced.
# 2023-12-20 15:06:14,793 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 106 had 292 pixels replaced.
# 2023-12-20 15:06:14,965 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 107 had 293 pixels replaced.
# 2023-12-20 15:06:15,901 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 108 had 293 pixels replaced.
# 2023-12-20 15:06:16,071 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 109 had 295 pixels replaced.
# 2023-12-20 15:06:16,254 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 110 had 293 pixels replaced.
# 2023-12-20 15:06:16,420 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 111 had 292 pixels replaced.
# 2023-12-20 15:06:16,599 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 112 had 297 pixels replaced.
# 2023-12-20 15:06:16,769 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 113 had 295 pixels replaced.
# 2023-12-20 15:06:16,947 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 114 had 293 pixels replaced.
# 2023-12-20 15:06:17,124 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 115 had 294 pixels replaced.
# 2023-12-20 15:06:17,303 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 116 had 293 pixels replaced.
# 2023-12-20 15:06:17,472 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 117 had 292 pixels replaced.
# 2023-12-20 15:06:17,643 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 118 had 292 pixels replaced.
# 2023-12-20 15:06:17,821 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 119 had 296 pixels replaced.
# 2023-12-20 15:06:17,989 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 120 had 292 pixels replaced.
# 2023-12-20 15:06:18,161 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 121 had 292 pixels replaced.
# 2023-12-20 15:06:18,336 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 122 had 292 pixels replaced.
# 2023-12-20 15:06:18,506 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 123 had 292 pixels replaced.
# 2023-12-20 15:06:18,681 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 124 had 294 pixels replaced.
# 2023-12-20 15:06:18,863 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 125 had 292 pixels replaced.
# 2023-12-20 15:06:19,029 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 126 had 292 pixels replaced.
# 2023-12-20 15:06:19,211 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 127 had 294 pixels replaced.
# 2023-12-20 15:06:19,381 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 128 had 292 pixels replaced.
# 2023-12-20 15:06:19,551 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 129 had 292 pixels replaced.
# 2023-12-20 15:06:19,738 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 130 had 298 pixels replaced.
# 2023-12-20 15:06:19,919 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 131 had 294 pixels replaced.
# 2023-12-20 15:06:20,092 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 132 had 293 pixels replaced.
# 2023-12-20 15:06:20,264 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 133 had 297 pixels replaced.
# 2023-12-20 15:06:20,449 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 134 had 299 pixels replaced.
# 2023-12-20 15:06:20,622 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 135 had 297 pixels replaced.
# 2023-12-20 15:06:20,792 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 136 had 292 pixels replaced.
# 2023-12-20 15:06:20,965 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 137 had 292 pixels replaced.
# 2023-12-20 15:06:21,138 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 138 had 297 pixels replaced.
# 2023-12-20 15:06:21,310 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 139 had 294 pixels replaced.
# 2023-12-20 15:06:21,480 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 140 had 292 pixels replaced.
# 2023-12-20 15:06:21,651 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 141 had 294 pixels replaced.
# 2023-12-20 15:06:21,820 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 142 had 293 pixels replaced.
# 2023-12-20 15:06:21,990 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 143 had 292 pixels replaced.
# 2023-12-20 15:06:22,160 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 144 had 292 pixels replaced.
# 2023-12-20 15:06:22,329 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 145 had 292 pixels replaced.
# 2023-12-20 15:06:22,499 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 146 had 292 pixels replaced.
# 2023-12-20 15:06:22,668 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 147 had 292 pixels replaced.
# 2023-12-20 15:06:22,839 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 148 had 293 pixels replaced.
# 2023-12-20 15:06:23,008 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 149 had 296 pixels replaced.
# 2023-12-20 15:06:23,180 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 150 had 292 pixels replaced.
# 2023-12-20 15:06:23,350 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 151 had 294 pixels replaced.
# 2023-12-20 15:06:23,521 - stpipe.Spec2Pipeline.pixel_replace - INFO - Input TSO integration 152 had 292 pixels replaced.
# ...
# 2023-12-20 15:09:07,607 - stpipe.Spec2Pipeline.extract_1d - INFO - Using extraction limits: xstart=0, xstop=2047, ystart=2.5, ystop=28.5
# 2023-12-20 15:09:07,822 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 2
# 2023-12-20 15:09:08,034 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 3
# 2023-12-20 15:09:08,258 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 4
# 2023-12-20 15:09:08,480 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 5
# 2023-12-20 15:09:08,703 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 6
# 2023-12-20 15:09:08,922 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 7
# 2023-12-20 15:09:09,140 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 8
# 2023-12-20 15:09:09,360 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 9
# 2023-12-20 15:09:09,579 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 10
# 2023-12-20 15:09:09,799 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 11
# 2023-12-20 15:09:10,016 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 12
# 2023-12-20 15:09:10,236 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 13
# 2023-12-20 15:09:10,454 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 14
# 2023-12-20 15:09:10,672 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 15
# 2023-12-20 15:09:10,889 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 16
# 2023-12-20 15:09:11,107 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 17
# 2023-12-20 15:09:11,323 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 18
# 2023-12-20 15:09:11,538 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 19
# 2023-12-20 15:09:11,756 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 20
# 2023-12-20 15:09:11,972 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 21
# 2023-12-20 15:09:12,189 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 22
# 2023-12-20 15:09:12,407 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 23
# 2023-12-20 15:09:12,624 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 24
# 2023-12-20 15:09:12,840 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 25
# 2023-12-20 15:09:13,059 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 26
# 2023-12-20 15:09:13,280 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 27
# 2023-12-20 15:09:13,497 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 28
# 2023-12-20 15:09:13,716 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 29
# 2023-12-20 15:09:13,935 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 30
# 2023-12-20 15:09:14,152 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 31
# 2023-12-20 15:09:14,370 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 32
# 2023-12-20 15:09:14,591 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 33
# 2023-12-20 15:09:14,811 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 34
# 2023-12-20 15:09:15,029 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 35
# 2023-12-20 15:09:15,250 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 36
# 2023-12-20 15:09:15,472 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 37
# 2023-12-20 15:09:15,687 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 38
# 2023-12-20 15:09:15,905 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 39
# 2023-12-20 15:09:16,123 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 40
# 2023-12-20 15:09:16,340 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 41
# 2023-12-20 15:09:16,556 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 42
# 2023-12-20 15:09:16,775 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 43
# 2023-12-20 15:09:16,994 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 44
# 2023-12-20 15:09:17,210 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 45
# 2023-12-20 15:09:17,428 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 46
# 2023-12-20 15:09:17,643 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 47
# 2023-12-20 15:09:17,862 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 48
# 2023-12-20 15:09:18,083 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 49
# 2023-12-20 15:09:18,298 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 50
# 2023-12-20 15:09:18,516 - stpipe.Spec2Pipeline.extract_1d - INFO - ... 50 integrations done
# 2023-12-20 15:09:18,517 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 51
# 2023-12-20 15:09:18,733 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 52
# 2023-12-20 15:09:18,950 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 53
# 2023-12-20 15:09:19,170 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 54
# 2023-12-20 15:09:19,389 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 55
# 2023-12-20 15:09:19,608 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 56
# 2023-12-20 15:09:19,824 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 57
# 2023-12-20 15:09:20,045 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 58
# 2023-12-20 15:09:20,262 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 59
# 2023-12-20 15:09:20,481 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 60
# 2023-12-20 15:09:20,702 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 61
# 2023-12-20 15:09:20,919 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 62
# 2023-12-20 15:09:21,137 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 63
# 2023-12-20 15:09:21,355 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 64
# 2023-12-20 15:09:21,570 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 65
# 2023-12-20 15:09:21,789 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 66
# 2023-12-20 15:09:22,008 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 67
# 2023-12-20 15:09:22,224 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 68
# 2023-12-20 15:09:22,444 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 69
# 2023-12-20 15:09:22,663 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 70
# 2023-12-20 15:09:22,880 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 71
# 2023-12-20 15:09:23,098 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 72
# 2023-12-20 15:09:23,316 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 73
# 2023-12-20 15:09:23,532 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 74
# 2023-12-20 15:09:23,748 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 75
# 2023-12-20 15:09:23,966 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 76
# 2023-12-20 15:09:24,185 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 77
# 2023-12-20 15:09:24,402 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 78
# 2023-12-20 15:09:24,618 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 79
# 2023-12-20 15:09:24,831 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 80
# 2023-12-20 15:09:25,047 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 81
# 2023-12-20 15:09:25,257 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 82
# 2023-12-20 15:09:25,467 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 83
# 2023-12-20 15:09:25,673 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 84
# 2023-12-20 15:09:25,889 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 85
# 2023-12-20 15:09:26,105 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 86
# 2023-12-20 15:09:26,325 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 87
# 2023-12-20 15:09:26,543 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 88
# 2023-12-20 15:09:26,759 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 89
# 2023-12-20 15:09:26,973 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 90
# 2023-12-20 15:09:27,188 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 91
# 2023-12-20 15:09:27,406 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 92
# 2023-12-20 15:09:27,622 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 93
# 2023-12-20 15:09:27,840 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 94
# 2023-12-20 15:09:28,055 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 95
# 2023-12-20 15:09:28,275 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 96
# 2023-12-20 15:09:28,492 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 97
# 2023-12-20 15:09:28,708 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 98
# 2023-12-20 15:09:28,925 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 99
# 2023-12-20 15:09:29,143 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 100
# 2023-12-20 15:09:29,362 - stpipe.Spec2Pipeline.extract_1d - INFO - ... 100 integrations done
# 2023-12-20 15:09:29,362 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 101
# 2023-12-20 15:09:29,581 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 102
# 2023-12-20 15:09:29,797 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 103
# 2023-12-20 15:09:30,015 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 104
# 2023-12-20 15:09:30,233 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 105
# 2023-12-20 15:09:30,452 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 106
# 2023-12-20 15:09:30,669 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 107
# 2023-12-20 15:09:30,887 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 108
# 2023-12-20 15:09:31,107 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 109
# 2023-12-20 15:09:31,325 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 110
# 2023-12-20 15:09:31,545 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 111
# 2023-12-20 15:09:31,764 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 112
# 2023-12-20 15:09:31,980 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 113
# 2023-12-20 15:09:32,199 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 114
# 2023-12-20 15:09:32,416 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 115
# 2023-12-20 15:09:32,634 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 116
# 2023-12-20 15:09:32,854 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 117
# 2023-12-20 15:09:33,070 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 118
# 2023-12-20 15:09:33,287 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 119
# 2023-12-20 15:09:33,503 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 120
# 2023-12-20 15:09:33,720 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 121
# 2023-12-20 15:09:33,934 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 122
# 2023-12-20 15:09:34,151 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 123
# 2023-12-20 15:09:34,368 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 124
# 2023-12-20 15:09:34,585 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 125
# 2023-12-20 15:09:34,800 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 126
# 2023-12-20 15:09:35,019 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 127
# 2023-12-20 15:09:35,236 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 128
# 2023-12-20 15:09:35,453 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 129
# 2023-12-20 15:09:35,671 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 130
# 2023-12-20 15:09:35,886 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 131
# 2023-12-20 15:09:36,101 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 132
# 2023-12-20 15:09:36,319 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 133
# 2023-12-20 15:09:36,535 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 134
# 2023-12-20 15:09:36,751 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 135
# 2023-12-20 15:09:36,966 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 136
# 2023-12-20 15:09:37,181 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 137
# 2023-12-20 15:09:37,397 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 138
# 2023-12-20 15:09:37,614 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 139
# 2023-12-20 15:09:37,831 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 140
# 2023-12-20 15:09:38,046 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 141
# 2023-12-20 15:09:38,262 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 142
# 2023-12-20 15:09:38,480 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 143
# 2023-12-20 15:09:38,696 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 144
# 2023-12-20 15:09:38,916 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 145
# 2023-12-20 15:09:39,130 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 146
# 2023-12-20 15:09:39,346 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 147
# 2023-12-20 15:09:39,557 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 148
# 2023-12-20 15:09:39,770 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 149
# 2023-12-20 15:09:39,980 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 150
# 2023-12-20 15:09:40,192 - stpipe.Spec2Pipeline.extract_1d - INFO - ... 150 integrations done
# 2023-12-20 15:09:40,193 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 151
# 2023-12-20 15:09:40,407 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 152
# 2023-12-20 15:09:40,622 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 153
# 2023-12-20 15:09:40,842 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 154
# 2023-12-20 15:09:41,059 - stpipe.Spec2Pipeline.extract_1d - INFO - Extracting integration 155
# 2023-12-20 15:09:41,276 - stpipe.Spec2Pipeline.extract_1d - INFO - All 155 integrations done
# 2023-12-20 15:09:47,671 - stpipe.Spec2Pipeline.extract_1d - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/jw01366003001_04101_00001-seg003_nrs2_rateints_1cl_x1dints.fits
# 2023-12-20 15:09:47,672 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-12-20 15:09:47,673 - stpipe.Spec2Pipeline - INFO - Finished processing product /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage1/jw01366003001_04101_00001-seg003_nrs2_rateints_1cl
# 2023-12-20 15:09:47,678 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2023-12-20 15:09:47,679 - stpipe.Spec2Pipeline - INFO - Results used CRDS context: jwst_1094.pmap
# 2023-12-20 15:09:47,964 - stpipe.Spec2Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/jw01366003001_04101_00001-seg003_nrs2_rateints_1cl_calints.fits
# 2023-12-20 15:09:47,965 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# Run time:  4.051666666666667  min

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Spec2](#stage2)

# %% [markdown]
# Plot extracted spectra for a visual inspection.

# %%
x1d = datamodels.open(stage2_dir + froot[0] + 'rateints_1cl_x1dints.fits')

#x1d.info(max_rows=None) # prints the full contents
x1d.info(max_rows=10)
#print(x1d)

# Obtain the wavelength and flux from 1d spectral products 
x1d_wave = x1d.spec[0].spec_table.WAVELENGTH
x1d_flux = x1d.spec[0].spec_table.FLUX


wave_um   = x1d_wave
all_times = x1d.int_times.int_mid_BJD_TDB
#print(len(all_times))

n_spec = len(x1d.spec)
n_pix  = len(x1d.spec[0].spec_table.FLUX)
#print(n_spec)
# Out:
# root (AsdfObject)
# ├─asdf_library (Software)
# │ ├─author (str): The ASDF Developers
# │ └─3 not shown
# ├─history (dict) ...
# ├─_fits_hash (str): 5da84886f103ca7b7cd89bbcc526448b97591c37fef2eaa9a55c8d0822ae1ad0
# ├─int_times (FITS_rec): shape=(155,), dtype=void416
# ├─meta (dict) ...
# └─spec (list) ...
# Some nodes not shown.

# %% [markdown]
# Next, we will load all of the extracted spectra and time stamps in one big array for easier analysis and plotting.

# %%
# Obtain all spectra for the list of segments
for i in (range(len(froot))):
    print("Processing segment: ", i+1, ' out of ', len(froot), ': ', froot[i] + 'rateints_1cl_x1dints.fits')
    x1d = datamodels.open(stage2_dir + froot[i] + 'rateints_1cl_x1dints.fits')
    
    n_spec = len(x1d.spec)
    n_pix  = len(x1d.spec[i].spec_table.FLUX)

    seg_spec_1D   = np.zeros([n_spec, n_pix])

    for j in range(len(x1d.spec)):
        seg_spec_1D[j,:]   = x1d.spec[j].spec_table.FLUX
    
    if i == 0:
        all_spec_1D = seg_spec_1D
        all_times   = x1d.int_times.int_mid_BJD_TDB
    if i > 0:
        all_spec_1D = np.concatenate((all_spec_1D, seg_spec_1D), axis = 0)
        all_times = np.concatenate((all_times, x1d.int_times.int_mid_BJD_TDB), axis = 0)
    

print(' ')
print('Total number of time stamps: ', len(all_times))
print('Total number of 1D spectra:  ', len(all_spec_1D[:,0]))
print(' ')
print('Total number of columns: ', len(all_spec_1D[0,:]))
print('Total length of wavemap: ', len(wave_um))
print(' ')

# We will also trim several columns at the start and end of the spectra. These belong to the reference pixels and are marked 'nan'.
print('Trimming first/last 5 refeerence pixels with nan-values ...')
all_spec_1D = all_spec_1D[:,5:-5]
wave_um  = wave_um[5:-5]
# Out:
# Processing segment:  1  out of  3 :  jw01366003001_04101_00001-seg001_nrs2_rateints_1cl_x1dints.fits
# Processing segment:  2  out of  3 :  jw01366003001_04101_00001-seg002_nrs2_rateints_1cl_x1dints.fits
# Processing segment:  3  out of  3 :  jw01366003001_04101_00001-seg003_nrs2_rateints_1cl_x1dints.fits
#
# Total number of time stamps:  465
# Total number of 1D spectra:   465
#
# Total number of columns:  2048
# Total length of wavemap:  2048
#
# Trimming first/last 5 refeerence pixels with nan-values ...

# %%
# Plot three spectra with offset

fig = plt.figure(figsize=(14, 8))
#plt.plot(x1d_nrs1_wave, x1d_nrs1_flux)
plt.plot(wave_um, all_spec_1D[0,:]-0.0)
plt.plot(wave_um, all_spec_1D[10,:]-70.0)
plt.plot(wave_um, all_spec_1D[100,:]-140.0)

plt.xlabel('Wavelength (microns)')
#plt.yscale('log')
plt.ylabel('Flux (Jy) + Constant offset')

if (process_detector == 'nrs1'):
    plt.xlim(2.8,3.8)
if (process_detector == 'nrs2'):
    plt.xlim(3.8,5.2)
#plt.ylim(-0.01,0.04)
plt.grid(True)
plt.show()

# %% [markdown]
# Next, we obtain a white light curve by taking the total flux between columns 20 to tha last-20, and plot the result along with light curve scatter.

# %%
n_spec = len(all_times)

# Obtain white light curve
wlc_flux = np.zeros(n_spec)

for i in range(n_spec):
    if (process_detector == 'nrs1'):
        wlc_flux[i] = np.nansum(all_spec_1D[i,20:-20])
    if (process_detector == 'nrs2'):
        wlc_flux[i] = np.nansum(all_spec_1D[i,5:-5])

# Normalize by the median flux of the first twenty points
wlc_flux /= np.median(wlc_flux[0:20])

# Plot
plt.figure(figsize=(12, 5))
sigma_wlc = np.sqrt(np.nanvar(wlc_flux[2:100]))
plt.plot((all_times-np.nanmean(all_times))*24., wlc_flux, color='red', marker="o", markersize=2, label=f'White light curve, (r.m.s.={round(sigma_wlc*1e6, 0)} ppm)')
plt.legend(loc='lower right')
plt.title('White Light Curve for ' + process_detector.upper() + f', $\lambda=${round(wave_um[20], 4)} - {round(wave_um[-20], 4)} $\mu$m', fontsize=15)
plt.xlabel('Time since mid-exposure, hr', fontsize=15)
plt.ylabel('Normalized flux', fontsize=15)
#plt.xlim([1, nintegrations])
if (process_detector == 'nrs1'):
    plt.ylim([0.965,1.003])
if (process_detector == 'nrs2'):
    plt.ylim([0.965,1.015])
#plt.xlim([-4.2,-0.5])

plt.show()

print('White Light Curve scatter (ppm):  ', round(sigma_wlc*1e6, 0))
# Out:
# White Light Curve scatter (ppm):   548.0

# %% [markdown]
# The white light curve shows relatively low scatter (230 and 548 ppm for NRS1 and NRS2, respectively) and exhibits the morphology of a transit event along with a step-function flux jump near the mid-transit. This flux jump (a decrease of flux in this case) is attributed to a 'tilt' event, associated with one of the segments of the JWST mirror. A 'tilt' event is considered any uncommanded change in the tip tilt orientation of a mirror segment, and can be caused by a micrometeorite impact. For further details, please consult the following page: <a href="https://jwst-docs.stsci.edu/methods-and-roadmaps/jwst-time-series-observations/jwst-time-series-observations-noise-sources">JWST TSO noise sources.</a>

# %%
lc_map = np.copy(all_spec_1D)
# 
spec_xlen = len(lc_map[0,:])


correct_tilt_event = 'yes'

for j in range(spec_xlen):
    # Normalize with each spectral line (removes throughput)
    lc_map[:,j] /= np.nanmean(lc_map[0:170,j])
    if correct_tilt_event == 'yes':
        # Correct for tilt event
        lc_map[270:,j] /= np.nanmean(lc_map[330:460,j])


mfactor = 1.6
plt.figure(figsize=(5*mfactor,8*mfactor))
plt.subplot(211)
plt.title('Spectroscopic light curves for ' + process_detector.upper(), fontsize=15)
im1 = plt.imshow(lc_map, 
                 interpolation='bilinear', 
                 aspect='auto', 
                 cmap='inferno_r', 
                 origin='lower', clim=(0.977, 1.005 ))

#plt.xlabel(r'Wavelength, $\mu$m', fontsize=15)
plt.xlabel(r'x-column, pixel', fontsize=15)
plt.ylabel('Integration ', fontsize=15)

# Suppress axis
#plt.axis('off')

#plt.axes()
#secax = axes().secondary_yaxis('right', functions=(RPRS_TO_H, H_TO_RPRS))
#secax.set_ylabel('Pressure scale height')

cb1 = plt.colorbar(label=r'Normalized Flux')

plt.show()

# %% [markdown]
# The plot above shows all extracted 1d spectra covering the transit event. The horizontal axis is the spectral direction (wavelength) and the vertical - each integration. The dark pixels correspond to the out-of-transit data (pre/post transit), the orange horizontal stripes indicate the ingress and egress portions, and the yellow stripe shows the in-transit part of the light curve. Please note, we have corrected the tilt event data by normalizing all spectra after integration 330 using the post transit flux.
#
# We now have white and spectroscopic light curves, which are ready for fitting (not covered in this notebook). In case there is need to identify spectral trace and obtain centroid information for the time series, please consult the following notebook that offers workaround solutions for Spec2 with additional analysis and features, presented on a JWebbinar in December 2023: <a href="https://github.com/exonik/JWebbinar2023-TSO/blob/main/Part2-Spec2.ipynb">Part2-Spec2.ipynb</a>
#
# It should be pointed out that the workaround solutions lead to a lower white light curve scatter for this particular data set (approximately 70 ppm lower, or 160ppm for NRS1). The difference is determined by two factors:
# 1. The pixel replacement step in the workaround makes use of the nominal psf profile to identify high and low pixels in addition to the data quality flags, and
# 2. At the time of writing the pixel replace step is unavailalbe in the STScI pipeline. Instead, in the workaround notebook, we fit for the centroid of the star to locate and trace the spectra (without resampling) and perform aperture extraction using the trace.
#
# The rest of this notebook demonstrates how to rerun the third and final stage of the STScI pipeline, which extracts the spectra (yes, again) and produces a white light curve, which we already did.

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 2](#stage2)

# %% [markdown]
# ---
# ### <font color='white'>-</font>Stage 3: Tso3Pipeline<a class="anchor" id="stage3"></a>
#
# ---
#
# The stage 3 TSO pipeline is applied to associations (json files) of calibrated BOTS exposures and produces calibrated spectra and white light curve of the source object. For details, please consult  <a href="https://jwst-pipeline.readthedocs.io/en/latest/jwst/pipeline/calwebb_tso3.html">calwebb_tso3: Stage 3 Time-Series Observation(TSO) Processing.</a>
#
# To be able to run TSO3Pipeline, we need to modify the association file to have only the science exposures of the detector we analyze. We need to exclude the target acquisition exposures from the members of the association. The next cell performs this task.

# %%
# open file in read-mode
with open(stage2_dir + asn_spec3_file, 'r') as file:
    # read JSON data
    data = json.load(file)

# Print json contents to screen
#print(json.dumps(data, indent=2))

#print(data['products'][0]['members'][0]['expname'])
#print(len(data['products'][0]['members']))

#idx = []

for i in range(len(data['products'][0]['members'])):
    
    # Print to screen identify the correct member
    #print(data['products'][0]['members'][i]['exptype'])
    #print(data['products'][0]['members'][i]['expname'][0:38]+'rateints_1cl_calints.fits')

    # Rename the members to match the filenames of the 1/f - corrected files 
    data['products'][0]['members'][i]['expname'] = data['products'][0]['members'][i]['expname'][0:38]+'rateints_1cl_calints.fits'
    #print(data['products'][0]['members'][i]['expname'])

    # Identify the indexes of the target acquisition exposures
    #if (data['products'][0]['members'][i]['exptype'] == 'target_acquisition'):
        #idx.append(i) 
        #print(data['products'][0]['members'][i])

# Print the ideces to screen and remove the entries from the association 
#print(idx)
#del data['products'][0]['members'][idx[0]-1]
#del data['products'][0]['members'][idx[1]-1]





if (process_detector == 'nrs1'):
    del data['products'][0]['members'][7]
    del data['products'][0]['members'][6]
    del data['products'][0]['members'][5]
    del data['products'][0]['members'][3]
    del data['products'][0]['members'][1]

if (process_detector == 'nrs2'):
    del data['products'][0]['members'][7]
    del data['products'][0]['members'][6]
    del data['products'][0]['members'][4]
    del data['products'][0]['members'][2]
    del data['products'][0]['members'][0]

 




# Save the modified association as a new file
newData = json.dumps(data, indent=4)
with open(stage2_dir + asn_spec3_file[:-5] + '_'+process_detector+'.json', 'w') as file: # add the suffix '_bots' to distinguish the file from the default version.
    # write
    file.write(newData)

# %% [markdown]
# We will once again modify the `extract_1d` parameter reference file to adjust the size of extracting aperture. This is needed, because the pipeline currently does not resample the 2D spectra to rectify the spectral curvature. We therefore rely on a large extraction aperture and prvude the 1/f-noise corrected 2D spectra.

# %%
import json

json_name = 'jwst_nirspec_extract1d_0006.json'
json_dir = os.environ['CRDS_PATH'] + '/references/jwst/nirspec/'

# open file in read-mode
with open(json_dir + json_name, 'r') as file:
    # read JSON data
    data = json.load(file)
    if (process_detector == 'nrs1'):
        data['apertures'][0]['extract_width'] = 6 # extraction aperture radius in pixels
        data['apertures'][0]['xstart'] = 100 # lower x-index 
    if process_detector == 'nrs2':
        data['apertures'][0]['extract_width'] = 27 # extraction aperture radius in pixels        
#    data['apertures'][0]['xstop'] = 300 # upper x-index
#    data['apertures'][0]['ystart'] = 5
#    data['apertures'][0]['ystop'] = 25
#    data['apertures'][0]['nod2_offset'] = 0 # apply no offsets
    data['apertures'][0].pop("nod2_offset") # remove
#    data['apertures'][0]['nod3_offset'] = 0
    data['apertures'][0].pop("nod3_offset") # remove
    #data['apertures'][0]['nod5_offset'] = 0
    data['apertures'][0].pop("nod5_offset") # remove
#    print(data['apertures'][0]['extract_width'])

newData = json.dumps(data, indent=4)
#print(json_name[:-5])
with open(json_dir + json_name[:-5] + '_bots.json', 'w') as file: # add the suffix '_bots' to distinguish the file from the default version.
    # write
    file.write(newData)

# %%
from jwst.pipeline import Tso3Pipeline

# %%
param_stage3 = {
    'outlier_detection' :{'skip': True},
    'extract_1d'        :{'skip': False, 'override_extract1d': f'{json_dir + json_name[:-5]}_bots.json', 'apply_apcorr': False, 'subtract_background': False }, # 'dispaxis': 1, 'xstart': 100, 'xstop': 150, 'extract_width': 10},
    'white_light'       :{'skip': False}
}


start = tt.time()

Tso3Pipeline.call(stage2_dir + asn_spec3_file[:-5] + '_'+process_detector+'.json', 
                  save_results = True, 
                  steps        = param_stage3, 
                  output_dir   = stage3_dir)

end = tt.time()
print("Run time: ", round(end-start,1)/60.0, " min")
# Out:
# 2023-12-20 16:48:10,454 - CRDS - ERROR -  Error determining best reference for 'pars-whitelightstep'  =   No match found.
# 2023-12-20 16:48:10,459 - stpipe.Tso3Pipeline - INFO - Tso3Pipeline instance created.
# 2023-12-20 16:48:10,460 - stpipe.Tso3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2023-12-20 16:48:10,461 - stpipe.Tso3Pipeline.tso_photometry - INFO - TSOPhotometryStep instance created.
# 2023-12-20 16:48:10,462 - stpipe.Tso3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2023-12-20 16:48:10,463 - stpipe.Tso3Pipeline.photom - INFO - PhotomStep instance created.
# 2023-12-20 16:48:10,464 - stpipe.Tso3Pipeline.white_light - INFO - WhiteLightStep instance created.
# 2023-12-20 16:48:11,397 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline running with args ('/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2/jw01366-o003_20230901t213306_tso3_00001_asn_nrs2.json',).
# 2023-12-20 16:48:11,400 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage3/', 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': True, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'scale_detection': False, 'steps': {'outlier_detection': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}, 'tso_photometry': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'save_catalog': False}, 'extract_1d': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': False, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': False, 'ifu_autocen': False, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}, 'photom': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '', 'inverse': False, 'source_type': None, 'mrs_time_correction': True}, 'white_light': {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.ecsv', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'whtlt', 'search_output_file': True, 'input_dir': '', 'min_wavelength': None, 'max_wavelength': None}}}
# 2023-12-20 16:48:11,682 - stpipe.Tso3Pipeline - INFO - Prefetching reference files for dataset: 'jw01366003001_04101_00001-seg001_nrs2_rateints_1cl_calints.fits' reftypes = ['gain', 'readnoise']
# 2023-12-20 16:48:11,685 - stpipe.Tso3Pipeline - INFO - Prefetch for GAIN reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_gain_0027.fits'.
# 2023-12-20 16:48:11,685 - stpipe.Tso3Pipeline - INFO - Prefetch for READNOISE reference file is '/Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_readnoise_0048.fits'.
# 2023-12-20 16:48:11,687 - stpipe.Tso3Pipeline - INFO - Starting calwebb_tso3...
# 2023-12-20 16:48:26,216 - stpipe.Tso3Pipeline - INFO - Performing outlier detection on input images ...
# 2023-12-20 16:48:27,225 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2023-12-20 16:48:27,226 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': None, 'search_output_file': False, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2023-12-20 16:48:27,227 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step skipped.
# 2023-12-20 16:48:27,527 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2023-12-20 16:48:41,695 - stpipe.Tso3Pipeline - INFO - Performing outlier detection on input images ...
# 2023-12-20 16:48:42,701 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2023-12-20 16:48:42,702 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'outlier_detection', 'search_output_file': False, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2023-12-20 16:48:42,702 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step skipped.
# 2023-12-20 16:48:43,002 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2023-12-20 16:48:57,117 - stpipe.Tso3Pipeline - INFO - Performing outlier detection on input images ...
# 2023-12-20 16:48:58,139 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<ModelContainer>,).
# 2023-12-20 16:48:58,141 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': True, 'suffix': 'outlier_detection', 'search_output_file': False, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'weight_type': 'ivm', 'pixfrac': 1.0, 'kernel': 'square', 'fillval': 'INDEF', 'nlow': 0, 'nhigh': 0, 'maskpt': 0.7, 'grow': 1, 'snr': '5.0 4.0', 'scale': '1.2 0.7', 'backg': 0.0, 'kernel_size': '7 7', 'threshold_percent': 99.8, 'ifu_second_check': False, 'save_intermediate_results': False, 'resample_data': True, 'good_bits': '~DO_NOT_USE', 'scale_detection': False, 'allowed_memory': None, 'in_memory': False}
# 2023-12-20 16:48:58,141 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step skipped.
# 2023-12-20 16:48:58,437 - stpipe.Tso3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2023-12-20 16:48:58,479 - stpipe.Tso3Pipeline - INFO - Extracting 1-D spectra ...
# 2023-12-20 16:48:59,390 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl_calints.fits>,).
# 2023-12-20 16:48:59,392 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': None, 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': False, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': False, 'ifu_autocen': False, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-12-20 16:48:59,493 - stpipe.Tso3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0006_bots.json
# 2023-12-20 16:48:59,493 - stpipe.Tso3Pipeline.extract_1d - INFO - APCORR reference file name is "N/A"
# 2023-12-20 16:48:59,494 - stpipe.Tso3Pipeline.extract_1d - INFO - APCORR will NOT be applied
# 2023-12-20 16:48:59,511 - stpipe.Tso3Pipeline.extract_1d - INFO - Processing spectral order -1
# 2023-12-20 16:48:59,511 - stpipe.Tso3Pipeline.extract_1d - WARNING - The photom step has not been run.
# 2023-12-20 16:48:59,512 - stpipe.Tso3Pipeline.extract_1d - INFO - Beginning loop over 155 integrations ...
# 2023-12-20 16:48:59,512 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 1
# 2023-12-20 16:48:59,523 - stpipe.Tso3Pipeline.extract_1d - INFO - Using extraction limits: xstart=0, xstop=2047, ystart=2.5, ystop=28.5
# 2023-12-20 16:48:59,735 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 2
# 2023-12-20 16:48:59,945 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 3
# 2023-12-20 16:49:00,161 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 4
# 2023-12-20 16:49:00,374 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 5
# 2023-12-20 16:49:00,592 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 6
# 2023-12-20 16:49:00,807 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 7
# 2023-12-20 16:49:01,026 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 8
# 2023-12-20 16:49:01,242 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 9
# 2023-12-20 16:49:01,453 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 10
# 2023-12-20 16:49:01,668 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 11
# 2023-12-20 16:49:01,885 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 12
# 2023-12-20 16:49:02,101 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 13
# 2023-12-20 16:49:02,318 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 14
# 2023-12-20 16:49:02,537 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 15
# 2023-12-20 16:49:02,756 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 16
# 2023-12-20 16:49:02,974 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 17
# 2023-12-20 16:49:03,192 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 18
# 2023-12-20 16:49:03,413 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 19
# 2023-12-20 16:49:03,637 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 20
# 2023-12-20 16:49:03,860 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 21
# 2023-12-20 16:49:04,083 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 22
# 2023-12-20 16:49:04,303 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 23
# 2023-12-20 16:49:04,525 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 24
# 2023-12-20 16:49:04,746 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 25
# 2023-12-20 16:49:04,965 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 26
# 2023-12-20 16:49:05,189 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 27
# 2023-12-20 16:49:05,408 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 28
# 2023-12-20 16:49:05,626 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 29
# 2023-12-20 16:49:05,844 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 30
# 2023-12-20 16:49:06,064 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 31
# 2023-12-20 16:49:06,284 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 32
# 2023-12-20 16:49:06,506 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 33
# 2023-12-20 16:49:06,726 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 34
# 2023-12-20 16:49:06,944 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 35
# 2023-12-20 16:49:07,159 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 36
# 2023-12-20 16:49:07,375 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 37
# 2023-12-20 16:49:07,595 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 38
# 2023-12-20 16:49:07,812 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 39
# 2023-12-20 16:49:08,030 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 40
# 2023-12-20 16:49:08,247 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 41
# 2023-12-20 16:49:08,464 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 42
# 2023-12-20 16:49:08,683 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 43
# 2023-12-20 16:49:08,901 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 44
# 2023-12-20 16:49:09,118 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 45
# 2023-12-20 16:49:09,335 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 46
# 2023-12-20 16:49:09,553 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 47
# 2023-12-20 16:49:09,771 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 48
# 2023-12-20 16:49:09,992 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 49
# 2023-12-20 16:49:10,211 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 50
# 2023-12-20 16:49:10,429 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 50 integrations done
# 2023-12-20 16:49:10,429 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 51
# 2023-12-20 16:49:10,650 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 52
# 2023-12-20 16:49:10,867 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 53
# 2023-12-20 16:49:11,084 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 54
# 2023-12-20 16:49:11,302 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 55
# 2023-12-20 16:49:11,519 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 56
# 2023-12-20 16:49:11,735 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 57
# 2023-12-20 16:49:11,953 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 58
# 2023-12-20 16:49:12,167 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 59
# 2023-12-20 16:49:12,384 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 60
# 2023-12-20 16:49:12,604 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 61
# 2023-12-20 16:49:12,820 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 62
# 2023-12-20 16:49:13,039 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 63
# 2023-12-20 16:49:13,260 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 64
# 2023-12-20 16:49:13,478 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 65
# 2023-12-20 16:49:13,695 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 66
# 2023-12-20 16:49:13,912 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 67
# 2023-12-20 16:49:14,128 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 68
# 2023-12-20 16:49:14,343 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 69
# 2023-12-20 16:49:14,560 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 70
# 2023-12-20 16:49:14,777 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 71
# 2023-12-20 16:49:14,996 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 72
# 2023-12-20 16:49:15,212 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 73
# 2023-12-20 16:49:15,430 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 74
# 2023-12-20 16:49:15,645 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 75
# 2023-12-20 16:49:15,864 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 76
# 2023-12-20 16:49:16,080 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 77
# 2023-12-20 16:49:16,297 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 78
# 2023-12-20 16:49:16,514 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 79
# 2023-12-20 16:49:16,728 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 80
# 2023-12-20 16:49:16,942 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 81
# 2023-12-20 16:49:17,146 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 82
# 2023-12-20 16:49:17,349 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 83
# 2023-12-20 16:49:17,552 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 84
# 2023-12-20 16:49:17,755 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 85
# 2023-12-20 16:49:17,961 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 86
# 2023-12-20 16:49:18,165 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 87
# 2023-12-20 16:49:18,382 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 88
# 2023-12-20 16:49:18,600 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 89
# 2023-12-20 16:49:18,818 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 90
# 2023-12-20 16:49:19,035 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 91
# 2023-12-20 16:49:19,254 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 92
# 2023-12-20 16:49:19,471 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 93
# 2023-12-20 16:49:19,687 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 94
# 2023-12-20 16:49:19,902 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 95
# 2023-12-20 16:49:20,120 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 96
# 2023-12-20 16:49:20,338 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 97
# 2023-12-20 16:49:20,557 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 98
# 2023-12-20 16:49:20,761 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 99
# 2023-12-20 16:49:20,977 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 100
# 2023-12-20 16:49:21,197 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 100 integrations done
# 2023-12-20 16:49:21,197 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 101
# 2023-12-20 16:49:21,414 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 102
# 2023-12-20 16:49:21,631 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 103
# 2023-12-20 16:49:21,848 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 104
# 2023-12-20 16:49:22,066 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 105
# 2023-12-20 16:49:22,282 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 106
# 2023-12-20 16:49:22,499 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 107
# 2023-12-20 16:49:22,715 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 108
# 2023-12-20 16:49:22,933 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 109
# 2023-12-20 16:49:23,149 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 110
# 2023-12-20 16:49:23,367 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 111
# 2023-12-20 16:49:23,583 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 112
# 2023-12-20 16:49:23,798 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 113
# 2023-12-20 16:49:24,017 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 114
# 2023-12-20 16:49:24,234 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 115
# 2023-12-20 16:49:24,453 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 116
# 2023-12-20 16:49:24,670 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 117
# 2023-12-20 16:49:24,879 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 118
# 2023-12-20 16:49:25,095 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 119
# 2023-12-20 16:49:25,313 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 120
# 2023-12-20 16:49:25,531 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 121
# 2023-12-20 16:49:25,747 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 122
# 2023-12-20 16:49:25,960 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 123
# 2023-12-20 16:49:26,178 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 124
# 2023-12-20 16:49:26,395 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 125
# 2023-12-20 16:49:26,608 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 126
# 2023-12-20 16:49:26,826 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 127
# 2023-12-20 16:49:27,041 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 128
# 2023-12-20 16:49:27,260 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 129
# 2023-12-20 16:49:27,477 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 130
# 2023-12-20 16:49:27,693 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 131
# 2023-12-20 16:49:27,911 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 132
# 2023-12-20 16:49:28,130 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 133
# 2023-12-20 16:49:28,345 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 134
# 2023-12-20 16:49:28,561 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 135
# 2023-12-20 16:49:28,776 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 136
# 2023-12-20 16:49:28,991 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 137
# 2023-12-20 16:49:29,207 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 138
# 2023-12-20 16:49:29,423 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 139
# 2023-12-20 16:49:29,643 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 140
# 2023-12-20 16:49:29,860 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 141
# 2023-12-20 16:49:30,077 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 142
# 2023-12-20 16:49:30,295 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 143
# 2023-12-20 16:49:30,510 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 144
# 2023-12-20 16:49:30,730 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 145
# 2023-12-20 16:49:30,999 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 146
# 2023-12-20 16:49:31,226 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 147
# 2023-12-20 16:49:31,449 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 148
# 2023-12-20 16:49:31,671 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 149
# 2023-12-20 16:49:31,898 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 150
# 2023-12-20 16:49:32,118 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 150 integrations done
# 2023-12-20 16:49:32,119 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 151
# 2023-12-20 16:49:32,345 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 152
# 2023-12-20 16:49:32,603 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 153
# 2023-12-20 16:49:32,818 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 154
# 2023-12-20 16:49:33,063 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 155
# 2023-12-20 16:49:33,279 - stpipe.Tso3Pipeline.extract_1d - INFO - All 155 integrations done
# 2023-12-20 16:49:34,093 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-12-20 16:49:34,681 - stpipe.Tso3Pipeline - INFO - Performing white-light photometry ...
# 2023-12-20 16:49:35,845 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light running with args (<MultiSpecModel from jw01366003001_04101_00001-seg001_nrs2_rateints_1cl_calints.fits>,).
# 2023-12-20 16:49:35,846 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.ecsv', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'whtlt', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'min_wavelength': None, 'max_wavelength': None}
# 2023-12-20 16:49:35,869 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light done
# 2023-12-20 16:49:35,870 - stpipe.Tso3Pipeline - INFO - Extracting 1-D spectra ...
# 2023-12-20 16:49:36,871 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg002_nrs2_rateints_1cl_calints.fits>,).
# 2023-12-20 16:49:36,873 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'extract_1d', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': False, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': False, 'ifu_autocen': False, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-12-20 16:49:36,977 - stpipe.Tso3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0006_bots.json
# 2023-12-20 16:49:36,977 - stpipe.Tso3Pipeline.extract_1d - INFO - APCORR reference file name is "N/A"
# 2023-12-20 16:49:36,978 - stpipe.Tso3Pipeline.extract_1d - INFO - APCORR will NOT be applied
# 2023-12-20 16:49:36,993 - stpipe.Tso3Pipeline.extract_1d - INFO - Processing spectral order -1
# 2023-12-20 16:49:36,993 - stpipe.Tso3Pipeline.extract_1d - WARNING - The photom step has not been run.
# 2023-12-20 16:49:36,994 - stpipe.Tso3Pipeline.extract_1d - INFO - Beginning loop over 155 integrations ...
# 2023-12-20 16:49:36,994 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 1
# 2023-12-20 16:49:36,997 - stpipe.Tso3Pipeline.extract_1d - INFO - Using extraction limits: xstart=0, xstop=2047, ystart=2.5, ystop=28.5
# 2023-12-20 16:49:37,216 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 2
# 2023-12-20 16:49:37,437 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 3
# 2023-12-20 16:49:37,657 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 4
# 2023-12-20 16:49:37,874 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 5
# 2023-12-20 16:49:38,092 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 6
# 2023-12-20 16:49:38,309 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 7
# 2023-12-20 16:49:38,529 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 8
# 2023-12-20 16:49:38,744 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 9
# 2023-12-20 16:49:38,963 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 10
# 2023-12-20 16:49:39,183 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 11
# 2023-12-20 16:49:39,403 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 12
# 2023-12-20 16:49:39,624 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 13
# 2023-12-20 16:49:39,842 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 14
# 2023-12-20 16:49:40,061 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 15
# 2023-12-20 16:49:40,281 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 16
# 2023-12-20 16:49:40,500 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 17
# 2023-12-20 16:49:40,713 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 18
# 2023-12-20 16:49:40,933 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 19
# 2023-12-20 16:49:41,151 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 20
# 2023-12-20 16:49:41,370 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 21
# 2023-12-20 16:49:41,589 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 22
# 2023-12-20 16:49:41,807 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 23
# 2023-12-20 16:49:42,027 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 24
# 2023-12-20 16:49:42,246 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 25
# 2023-12-20 16:49:42,464 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 26
# 2023-12-20 16:49:42,683 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 27
# 2023-12-20 16:49:42,902 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 28
# 2023-12-20 16:49:43,124 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 29
# 2023-12-20 16:49:43,346 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 30
# 2023-12-20 16:49:43,564 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 31
# 2023-12-20 16:49:43,786 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 32
# 2023-12-20 16:49:44,006 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 33
# 2023-12-20 16:49:44,221 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 34
# 2023-12-20 16:49:44,439 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 35
# 2023-12-20 16:49:44,658 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 36
# 2023-12-20 16:49:44,875 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 37
# 2023-12-20 16:49:45,091 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 38
# 2023-12-20 16:49:45,308 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 39
# 2023-12-20 16:49:45,525 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 40
# 2023-12-20 16:49:45,740 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 41
# 2023-12-20 16:49:45,952 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 42
# 2023-12-20 16:49:46,167 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 43
# 2023-12-20 16:49:46,383 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 44
# 2023-12-20 16:49:46,601 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 45
# 2023-12-20 16:49:46,810 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 46
# 2023-12-20 16:49:47,013 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 47
# 2023-12-20 16:49:47,215 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 48
# 2023-12-20 16:49:47,433 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 49
# 2023-12-20 16:49:47,650 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 50
# 2023-12-20 16:49:47,863 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 50 integrations done
# 2023-12-20 16:49:47,864 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 51
# 2023-12-20 16:49:48,075 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 52
# 2023-12-20 16:49:48,288 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 53
# 2023-12-20 16:49:48,498 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 54
# 2023-12-20 16:49:48,704 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 55
# 2023-12-20 16:49:48,919 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 56
# 2023-12-20 16:49:49,139 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 57
# 2023-12-20 16:49:49,361 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 58
# 2023-12-20 16:49:49,587 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 59
# 2023-12-20 16:49:49,812 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 60
# 2023-12-20 16:49:50,039 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 61
# 2023-12-20 16:49:50,262 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 62
# 2023-12-20 16:49:50,486 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 63
# 2023-12-20 16:49:50,706 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 64
# 2023-12-20 16:49:50,927 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 65
# 2023-12-20 16:49:51,148 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 66
# 2023-12-20 16:49:51,370 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 67
# 2023-12-20 16:49:51,589 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 68
# 2023-12-20 16:49:51,806 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 69
# 2023-12-20 16:49:52,026 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 70
# 2023-12-20 16:49:52,243 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 71
# 2023-12-20 16:49:52,463 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 72
# 2023-12-20 16:49:52,684 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 73
# 2023-12-20 16:49:52,901 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 74
# 2023-12-20 16:49:53,120 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 75
# 2023-12-20 16:49:53,342 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 76
# 2023-12-20 16:49:53,559 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 77
# 2023-12-20 16:49:53,776 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 78
# 2023-12-20 16:49:53,993 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 79
# 2023-12-20 16:49:54,211 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 80
# 2023-12-20 16:49:54,430 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 81
# 2023-12-20 16:49:54,649 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 82
# 2023-12-20 16:49:54,866 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 83
# 2023-12-20 16:49:55,083 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 84
# 2023-12-20 16:49:55,299 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 85
# 2023-12-20 16:49:55,518 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 86
# 2023-12-20 16:49:55,736 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 87
# 2023-12-20 16:49:55,952 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 88
# 2023-12-20 16:49:56,170 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 89
# 2023-12-20 16:49:56,391 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 90
# 2023-12-20 16:49:56,609 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 91
# 2023-12-20 16:49:56,827 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 92
# 2023-12-20 16:49:57,043 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 93
# 2023-12-20 16:49:57,260 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 94
# 2023-12-20 16:49:57,474 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 95
# 2023-12-20 16:49:57,691 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 96
# 2023-12-20 16:49:57,905 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 97
# 2023-12-20 16:49:58,123 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 98
# 2023-12-20 16:49:58,342 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 99
# 2023-12-20 16:49:58,560 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 100
# 2023-12-20 16:49:58,775 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 100 integrations done
# 2023-12-20 16:49:58,776 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 101
# 2023-12-20 16:49:58,995 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 102
# 2023-12-20 16:49:59,215 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 103
# 2023-12-20 16:49:59,433 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 104
# 2023-12-20 16:49:59,653 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 105
# 2023-12-20 16:49:59,871 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 106
# 2023-12-20 16:50:00,091 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 107
# 2023-12-20 16:50:00,309 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 108
# 2023-12-20 16:50:00,530 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 109
# 2023-12-20 16:50:00,751 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 110
# 2023-12-20 16:50:00,972 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 111
# 2023-12-20 16:50:01,194 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 112
# 2023-12-20 16:50:01,414 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 113
# 2023-12-20 16:50:01,631 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 114
# 2023-12-20 16:50:01,847 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 115
# 2023-12-20 16:50:02,066 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 116
# 2023-12-20 16:50:02,280 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 117
# 2023-12-20 16:50:02,494 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 118
# 2023-12-20 16:50:02,710 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 119
# 2023-12-20 16:50:02,925 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 120
# 2023-12-20 16:50:03,140 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 121
# 2023-12-20 16:50:03,355 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 122
# 2023-12-20 16:50:03,566 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 123
# 2023-12-20 16:50:03,784 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 124
# 2023-12-20 16:50:04,005 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 125
# 2023-12-20 16:50:04,222 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 126
# 2023-12-20 16:50:04,437 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 127
# 2023-12-20 16:50:04,652 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 128
# 2023-12-20 16:50:04,871 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 129
# 2023-12-20 16:50:05,088 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 130
# 2023-12-20 16:50:05,306 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 131
# 2023-12-20 16:50:05,522 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 132
# 2023-12-20 16:50:05,739 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 133
# 2023-12-20 16:50:05,954 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 134
# 2023-12-20 16:50:06,169 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 135
# 2023-12-20 16:50:06,387 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 136
# 2023-12-20 16:50:06,606 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 137
# 2023-12-20 16:50:06,825 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 138
# 2023-12-20 16:50:07,048 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 139
# 2023-12-20 16:50:07,263 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 140
# 2023-12-20 16:50:07,480 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 141
# 2023-12-20 16:50:07,701 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 142
# 2023-12-20 16:50:07,923 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 143
# 2023-12-20 16:50:08,139 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 144
# 2023-12-20 16:50:08,359 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 145
# 2023-12-20 16:50:08,578 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 146
# 2023-12-20 16:50:08,796 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 147
# 2023-12-20 16:50:09,015 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 148
# 2023-12-20 16:50:09,232 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 149
# 2023-12-20 16:50:09,450 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 150
# 2023-12-20 16:50:09,668 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 150 integrations done
# 2023-12-20 16:50:09,669 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 151
# 2023-12-20 16:50:09,885 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 152
# 2023-12-20 16:50:10,103 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 153
# 2023-12-20 16:50:10,321 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 154
# 2023-12-20 16:50:10,538 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 155
# 2023-12-20 16:50:10,754 - stpipe.Tso3Pipeline.extract_1d - INFO - All 155 integrations done
# 2023-12-20 16:50:11,525 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-12-20 16:50:12,119 - stpipe.Tso3Pipeline - INFO - Performing white-light photometry ...
# 2023-12-20 16:50:13,233 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light running with args (<MultiSpecModel from jw01366003001_04101_00001-seg002_nrs2_rateints_1cl_calints.fits>,).
# 2023-12-20 16:50:13,234 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.ecsv', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'whtlt', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'min_wavelength': None, 'max_wavelength': None}
# 2023-12-20 16:50:13,258 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light done
# 2023-12-20 16:50:13,258 - stpipe.Tso3Pipeline - INFO - Extracting 1-D spectra ...
# 2023-12-20 16:50:14,288 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d running with args (<SlitModel(155, 32, 2048) from jw01366003001_04101_00001-seg003_nrs2_rateints_1cl_calints.fits>,).
# 2023-12-20 16:50:14,289 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.fits', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'extract_1d', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'smoothing_length': None, 'bkg_fit': None, 'bkg_order': None, 'bkg_sigma_clip': 3.0, 'log_increment': 50, 'subtract_background': False, 'use_source_posn': None, 'center_xy': None, 'apply_apcorr': False, 'ifu_autocen': False, 'ifu_rfcorr': False, 'ifu_set_srctype': None, 'ifu_rscale': None, 'soss_atoca': True, 'soss_threshold': 0.01, 'soss_n_os': 2, 'soss_wave_grid_in': None, 'soss_wave_grid_out': None, 'soss_estimate': None, 'soss_rtol': 0.0001, 'soss_max_grid_size': 20000, 'soss_transform': None, 'soss_tikfac': None, 'soss_width': 40.0, 'soss_bad_pix': 'masking', 'soss_modelname': None}
# 2023-12-20 16:50:14,397 - stpipe.Tso3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/nnikolov/Documents/Functional/crds_cache/jwst_ops/references/jwst/nirspec/jwst_nirspec_extract1d_0006_bots.json
# 2023-12-20 16:50:14,398 - stpipe.Tso3Pipeline.extract_1d - INFO - APCORR reference file name is "N/A"
# 2023-12-20 16:50:14,398 - stpipe.Tso3Pipeline.extract_1d - INFO - APCORR will NOT be applied
# 2023-12-20 16:50:14,413 - stpipe.Tso3Pipeline.extract_1d - INFO - Processing spectral order -1
# 2023-12-20 16:50:14,413 - stpipe.Tso3Pipeline.extract_1d - WARNING - The photom step has not been run.
# 2023-12-20 16:50:14,413 - stpipe.Tso3Pipeline.extract_1d - INFO - Beginning loop over 155 integrations ...
# 2023-12-20 16:50:14,414 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 1
# 2023-12-20 16:50:14,416 - stpipe.Tso3Pipeline.extract_1d - INFO - Using extraction limits: xstart=0, xstop=2047, ystart=2.5, ystop=28.5
# 2023-12-20 16:50:14,638 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 2
# 2023-12-20 16:50:14,858 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 3
# 2023-12-20 16:50:15,076 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 4
# 2023-12-20 16:50:15,294 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 5
# 2023-12-20 16:50:15,512 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 6
# 2023-12-20 16:50:15,732 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 7
# 2023-12-20 16:50:15,947 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 8
# 2023-12-20 16:50:16,167 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 9
# 2023-12-20 16:50:16,391 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 10
# 2023-12-20 16:50:16,611 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 11
# 2023-12-20 16:50:16,835 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 12
# 2023-12-20 16:50:17,056 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 13
# 2023-12-20 16:50:17,276 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 14
# 2023-12-20 16:50:17,493 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 15
# 2023-12-20 16:50:17,714 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 16
# 2023-12-20 16:50:17,935 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 17
# 2023-12-20 16:50:18,156 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 18
# 2023-12-20 16:50:18,378 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 19
# 2023-12-20 16:50:18,595 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 20
# 2023-12-20 16:50:18,813 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 21
# 2023-12-20 16:50:19,030 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 22
# 2023-12-20 16:50:19,248 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 23
# 2023-12-20 16:50:19,464 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 24
# 2023-12-20 16:50:19,681 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 25
# 2023-12-20 16:50:19,897 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 26
# 2023-12-20 16:50:20,117 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 27
# 2023-12-20 16:50:20,334 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 28
# 2023-12-20 16:50:20,551 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 29
# 2023-12-20 16:50:20,769 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 30
# 2023-12-20 16:50:20,985 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 31
# 2023-12-20 16:50:21,206 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 32
# 2023-12-20 16:50:21,426 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 33
# 2023-12-20 16:50:21,649 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 34
# 2023-12-20 16:50:21,868 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 35
# 2023-12-20 16:50:22,087 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 36
# 2023-12-20 16:50:22,310 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 37
# 2023-12-20 16:50:22,530 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 38
# 2023-12-20 16:50:22,752 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 39
# 2023-12-20 16:50:22,971 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 40
# 2023-12-20 16:50:23,189 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 41
# 2023-12-20 16:50:23,404 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 42
# 2023-12-20 16:50:23,622 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 43
# 2023-12-20 16:50:23,837 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 44
# 2023-12-20 16:50:24,053 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 45
# 2023-12-20 16:50:24,270 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 46
# 2023-12-20 16:50:24,487 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 47
# 2023-12-20 16:50:24,703 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 48
# 2023-12-20 16:50:24,921 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 49
# 2023-12-20 16:50:25,140 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 50
# 2023-12-20 16:50:25,356 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 50 integrations done
# 2023-12-20 16:50:25,357 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 51
# 2023-12-20 16:50:25,573 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 52
# 2023-12-20 16:50:25,789 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 53
# 2023-12-20 16:50:26,007 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 54
# 2023-12-20 16:50:26,224 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 55
# 2023-12-20 16:50:26,442 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 56
# 2023-12-20 16:50:26,662 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 57
# 2023-12-20 16:50:26,879 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 58
# 2023-12-20 16:50:27,099 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 59
# 2023-12-20 16:50:27,318 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 60
# 2023-12-20 16:50:27,537 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 61
# 2023-12-20 16:50:27,757 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 62
# 2023-12-20 16:50:27,977 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 63
# 2023-12-20 16:50:28,196 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 64
# 2023-12-20 16:50:28,420 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 65
# 2023-12-20 16:50:28,637 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 66
# 2023-12-20 16:50:28,854 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 67
# 2023-12-20 16:50:29,076 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 68
# 2023-12-20 16:50:29,296 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 69
# 2023-12-20 16:50:29,517 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 70
# 2023-12-20 16:50:29,737 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 71
# 2023-12-20 16:50:29,957 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 72
# 2023-12-20 16:50:30,211 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 73
# 2023-12-20 16:50:30,430 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 74
# 2023-12-20 16:50:30,649 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 75
# 2023-12-20 16:50:30,868 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 76
# 2023-12-20 16:50:31,089 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 77
# 2023-12-20 16:50:31,307 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 78
# 2023-12-20 16:50:31,528 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 79
# 2023-12-20 16:50:31,748 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 80
# 2023-12-20 16:50:31,965 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 81
# 2023-12-20 16:50:32,182 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 82
# 2023-12-20 16:50:32,401 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 83
# 2023-12-20 16:50:32,618 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 84
# 2023-12-20 16:50:32,836 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 85
# 2023-12-20 16:50:33,053 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 86
# 2023-12-20 16:50:33,283 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 87
# 2023-12-20 16:50:33,509 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 88
# 2023-12-20 16:50:33,727 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 89
# 2023-12-20 16:50:33,947 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 90
# 2023-12-20 16:50:34,166 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 91
# 2023-12-20 16:50:34,389 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 92
# 2023-12-20 16:50:34,604 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 93
# 2023-12-20 16:50:34,819 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 94
# 2023-12-20 16:50:35,124 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 95
# 2023-12-20 16:50:35,342 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 96
# 2023-12-20 16:50:35,564 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 97
# 2023-12-20 16:50:35,781 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 98
# 2023-12-20 16:50:36,000 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 99
# 2023-12-20 16:50:36,218 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 100
# 2023-12-20 16:50:36,435 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 100 integrations done
# 2023-12-20 16:50:36,436 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 101
# 2023-12-20 16:50:36,656 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 102
# 2023-12-20 16:50:36,876 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 103
# 2023-12-20 16:50:37,095 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 104
# 2023-12-20 16:50:37,315 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 105
# 2023-12-20 16:50:37,535 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 106
# 2023-12-20 16:50:37,755 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 107
# 2023-12-20 16:50:37,970 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 108
# 2023-12-20 16:50:38,184 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 109
# 2023-12-20 16:50:38,398 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 110
# 2023-12-20 16:50:38,616 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 111
# 2023-12-20 16:50:38,830 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 112
# 2023-12-20 16:50:39,042 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 113
# 2023-12-20 16:50:39,256 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 114
# 2023-12-20 16:50:39,472 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 115
# 2023-12-20 16:50:39,689 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 116
# 2023-12-20 16:50:39,908 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 117
# 2023-12-20 16:50:40,124 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 118
# 2023-12-20 16:50:40,340 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 119
# 2023-12-20 16:50:40,557 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 120
# 2023-12-20 16:50:40,776 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 121
# 2023-12-20 16:50:40,995 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 122
# 2023-12-20 16:50:41,212 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 123
# 2023-12-20 16:50:41,429 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 124
# 2023-12-20 16:50:41,646 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 125
# 2023-12-20 16:50:41,862 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 126
# 2023-12-20 16:50:42,082 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 127
# 2023-12-20 16:50:42,300 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 128
# 2023-12-20 16:50:42,517 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 129
# 2023-12-20 16:50:42,731 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 130
# 2023-12-20 16:50:42,946 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 131
# 2023-12-20 16:50:43,164 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 132
# 2023-12-20 16:50:43,384 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 133
# 2023-12-20 16:50:43,605 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 134
# 2023-12-20 16:50:43,829 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 135
# 2023-12-20 16:50:44,052 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 136
# 2023-12-20 16:50:44,272 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 137
# 2023-12-20 16:50:44,490 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 138
# 2023-12-20 16:50:44,710 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 139
# 2023-12-20 16:50:44,928 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 140
# 2023-12-20 16:50:45,149 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 141
# 2023-12-20 16:50:45,367 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 142
# 2023-12-20 16:50:45,586 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 143
# 2023-12-20 16:50:45,804 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 144
# 2023-12-20 16:50:46,022 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 145
# 2023-12-20 16:50:46,239 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 146
# 2023-12-20 16:50:46,456 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 147
# 2023-12-20 16:50:46,675 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 148
# 2023-12-20 16:50:46,891 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 149
# 2023-12-20 16:50:47,108 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 150
# 2023-12-20 16:50:47,327 - stpipe.Tso3Pipeline.extract_1d - INFO - ... 150 integrations done
# 2023-12-20 16:50:47,328 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 151
# 2023-12-20 16:50:47,544 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 152
# 2023-12-20 16:50:47,761 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 153
# 2023-12-20 16:50:47,979 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 154
# 2023-12-20 16:50:48,198 - stpipe.Tso3Pipeline.extract_1d - INFO - Extracting integration 155
# 2023-12-20 16:50:48,416 - stpipe.Tso3Pipeline.extract_1d - INFO - All 155 integrations done
# 2023-12-20 16:50:49,194 - stpipe.Tso3Pipeline.extract_1d - INFO - Step extract_1d done
# 2023-12-20 16:50:49,816 - stpipe.Tso3Pipeline - INFO - Performing white-light photometry ...
# 2023-12-20 16:50:50,972 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light running with args (<MultiSpecModel from jw01366003001_04101_00001-seg003_nrs2_rateints_1cl_calints.fits>,).
# 2023-12-20 16:50:50,973 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light parameters are: {'pre_hooks': [], 'post_hooks': [], 'output_file': None, 'output_dir': None, 'output_ext': '.ecsv', 'output_use_model': False, 'output_use_index': True, 'save_results': False, 'skip': False, 'suffix': 'whtlt', 'search_output_file': True, 'input_dir': '/Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage2', 'min_wavelength': None, 'max_wavelength': None}
# 2023-12-20 16:50:50,995 - stpipe.Tso3Pipeline.white_light - INFO - Step white_light done
# 2023-12-20 16:51:16,695 - stpipe.Tso3Pipeline - INFO - Saved model in /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage3/jw01366-o003_t001_nirspec_f290lp-g395h-s1600a1-sub2048_x1dints.fits
# 2023-12-20 16:51:16,698 - stpipe.Tso3Pipeline - INFO - Writing Level 3 photometry catalog /Users/nnikolov/Documents/Functional/NIRSpec/Pipeline_testing/20231211_NB_for_MClarke/stage3/jw01366-o003_t001_nirspec_f290lp-g395h-s1600a1-sub2048_whtlt.ecsv
# 2023-12-20 16:51:16,726 - stpipe.Tso3Pipeline - INFO - Step Tso3Pipeline done
# Run time:  3.11  min

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 2](#stage2), [Link to Stage 3](#stage3)

# %% [markdown]
# Read and plot the white light curve from the csv file

# %%
# Read the white light curve as an Astropy table
schema = {'data': '2D float64'}

data = Table.read(stage3_dir + 'jw01366-o003_t001_nirspec_f290lp-g395h-s1600a1-sub2048_whtlt.ecsv', format='ascii.ecsv', converters=schema)

tx = data['MJD']
ty = data['whitelight_flux']

xx = np.zeros(len(tx))
yy = np.zeros(len(tx))

for i in range(len(tx)):
    xx[i] = tx[i]
    yy[i] = ty[i]
    #print(tx[i])

yy = yy/np.median(yy[0:100])

print('sigma: ', np.std(yy[2:100])*1e6)



plt.figure(figsize=(12, 5))
sigma_wlc = np.sqrt(np.nanvar(yy[2:100]))
plt.plot((xx-np.nanmean(xx))*24., yy, color='blue', marker="o", markersize=2, label=f'White light curve, (r.m.s.={round(sigma_wlc*1e6, 0)} ppm)')
plt.legend(loc='lower right')
plt.title('White Light Curve for ' + process_detector.upper(), fontsize=15)
plt.xlabel('Time since mid-exposure, hr', fontsize=15)
plt.ylabel('Normalized flux', fontsize=15)
#plt.xlim([1, nintegrations])
if (process_detector == 'nrs1'):
    plt.ylim([0.965,1.003])
if (process_detector == 'nrs2'):
    plt.ylim([0.965,1.015])
#plt.xlim([-4.2,-0.5])

plt.show()

print('White Light Curve scatter (ppm):  ', round(sigma_wlc*1e6, 0))
# Out:
# sigma:  545.3799761410089
# White Light Curve scatter (ppm):   545.0

# %% [markdown]
# ---
#
# ### <font color='white'>-</font>5. Concluding remarks<a class="anchor" id="remarks"></a>
#
# ---

# %% [markdown]
# In this notebook, we demonstrated how to obtain white and spectroscopic light curves by running the three stages of the JWST pipeline and our custom steps. The saved data producs can now be provided to light curve fitting codes for measurements of the physical properties of the exoplanet and obtaining a transmission spectrum. It should be pointed out that the analyses performed here are only a subset of the possible analyses one can perform, and are in no way the final word on _how_ JWST data _should_ be analyzed. This will be solidified more and more as data comes and best practices are established in the current and future cycles.
#
# In conclusion, I would like to express my gratitude to the entire JWST team that has supported the creation of this notebook through discussions and testing, which have improved the notebook. In particular, special thanks to the Time-Series Observations Working Group at STScI, including Néstor Espinoza, Leonardo Ubeda, Sarah Kendrew, Elena Manjavacas, Brian Brooks, Mike Reagan, Loïc Albert, Everett Schlawin, Stephan Birkmann among others. To the NIRCam IDT team for multiple fruitful discussions, including Everett Schlawin, Thomas Beatty, Tom Greene and Jarron Leisenring. To the ERS Transiting Exoplanet team who have provided several venues for discussion and community input. To the several JWST team members, including behind the pipeline and the mission itself, including and in no particular order Bryan Hilbert, Armin Rest, Anton Koekemoer, Alicia Canipe, Melanie Clarke, James Muzerolle, Kayli Glidic, Jeff Valenti and Karl Gordon.

# %% [markdown]
# #### [Link to the Table of contents](#table)
# #### [Link to Stage 1](#stage1), [Link to Stage 2](#stage2), [Link to Stage 3](#stage3)
